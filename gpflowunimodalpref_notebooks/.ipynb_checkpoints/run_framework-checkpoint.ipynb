# %% [markdown]
# # Thermal Preference Elicitation Framework
#
# Currently, this framework has been validated for only 1D (operating temp) feature./

# %% [markdown]
# # Step 1
#
# Load required modules

# %%
import sys
sys.path.append('../')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy
sns.set_context("talk", font_scale = 1.4)
from GPFlowUnimodalPref.GPUnimodalElicit import elicit
from GPFlowUnimodalPref.SynOccupant import datagen
# Out:
# /Users/nimishawalgaonkar/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# # Step 2
#
# 1. Occupant walks inside the room and is exposed to state r.
# 2. Randomly change the state of the room to new state s.
# 3. Ask the occupant which state they prefer.
# 4. If they say state current state s, then record y as 1. If they say previous state r, then record y as 0.
# This first duel is our initial duel.
# 5. Put the duel value and response in the '../data/duels/duels.csv' file

# %%
# Load the duels file
data_file = '../GPFlowUnimodalPref/data/duels/duels3.csv' # <--- you need to keep on updating this file

# %%
data = pd.read_csv(data_file)
data # check if the duels data is as you want it to be
# Out:
#    Tprev  Tcurrent  y      MEUI
# 0   21.0     24.00  1  0.406000
# 1   24.0     27.00  1  0.001333
# 2   27.0     26.00  1  0.023210
# 3   26.0     23.00  0  0.000012
# 4   23.0     25.50  1  0.000193
# 5   25.5     26.50  1  0.000142
# 6   26.5     27.00  0       NaN
# 7   27.0     26.72  1       NaN

# %%
iter_num = data.shape[0]

# %%
Tprev = np.array(data.Tprev) # previous state (operating temp.)
Tcurrent = np.array(data.Tcurrent) # current state <---- elicitation framework will give you this values
X = np.vstack([[Tprev, Tcurrent]]).T
X = X.astype(float) # features need to be float
X_prime = np.linspace(20, 27, 40)[:,None]
Y = np.array(data.y)[:,None] # response of the occupant <---- you need to ask occupant about this

# %% [markdown]
# # Step 3
#
# Now, we want to find the next elicited state. So, we need to use **elicit** module.

# %%
config_file = '../GPFlowUnimodalPref/config_files/thermal_config.json' # configuration for grid (how fine you want to be)
trial_num = 10 # this is just to save all the plots in '../data/results/T1' if trial_num = 1 ; T2 if trial_num = 2
model_num = 1
mcmc = True
reachable = True
savefig = True

# %%
Aq =  elicit.IntegratedAquisition(X, Y, X_prime, config_file, model_num, mcmc, reachable)
# Out:
# ----------------------------------------
# Model is 1
# burn-in sampling started
# Iteration:  100 	 Acc Rate:  13.0 %
# Iteration:  200 	 Acc Rate:  67.0 %
# Iteration:  300 	 Acc Rate:  83.0 %
# Iteration:  400 	 Acc Rate:  72.0 %
# Iteration:  500 	 Acc Rate:  86.0 %
# Iteration:  600 	 Acc Rate:  81.0 %
# Iteration:  700 	 Acc Rate:  88.0 %
# Iteration:  800 	 Acc Rate:  87.0 %
# Iteration:  900 	 Acc Rate:  94.0 %
# Iteration:  1000 	 Acc Rate:  89.0 %
# Iteration:  1100 	 Acc Rate:  88.0 %
# Iteration:  1200 	 Acc Rate:  91.0 %
# Iteration:  1300 	 Acc Rate:  83.0 %
# Iteration:  1400 	 Acc Rate:  72.0 %
# Iteration:  1500 	 Acc Rate:  65.0 %
# Iteration:  1600 	 Acc Rate:  77.0 %
# Iteration:  1700 	 Acc Rate:  71.0 %
# Iteration:  1800 	 Acc Rate:  78.0 %
# Iteration:  1900 	 Acc Rate:  90.0 %
# Iteration:  2000 	 Acc Rate:  80.0 %
# Iteration:  2100 	 Acc Rate:  78.0 %
# Iteration:  2200 	 Acc Rate:  80.0 %
# Iteration:  2300 	 Acc Rate:  62.0 %
# Iteration:  2400 	 Acc Rate:  79.0 %
# Iteration:  2500 	 Acc Rate:  75.0 %
# Iteration:  2600 	 Acc Rate:  83.0 %
# Iteration:  2700 	 Acc Rate:  83.0 %
# Iteration:  2800 	 Acc Rate:  94.0 %
# Iteration:  2900 	 Acc Rate:  65.0 %
# Iteration:  3000 	 Acc Rate:  80.0 %
# burn-in sampling ended
# Iteration:  100 	 Acc Rate:  82.0 %
# Iteration:  200 	 Acc Rate:  80.0 %
# Iteration:  300 	 Acc Rate:  83.0 %
# Iteration:  400 	 Acc Rate:  94.0 %
# Iteration:  500 	 Acc Rate:  91.0 %
# Iteration:  600 	 Acc Rate:  75.0 %
# Iteration:  700 	 Acc Rate:  61.0 %
# Iteration:  800 	 Acc Rate:  69.0 %
# Iteration:  900 	 Acc Rate:  89.0 %
# Iteration:  1000 	 Acc Rate:  84.0 %
# Iteration:  1100 	 Acc Rate:  98.0 %
# Iteration:  1200 	 Acc Rate:  88.0 %
# Iteration:  1300 	 Acc Rate:  86.0 %
# Iteration:  1400 	 Acc Rate:  92.0 %
# Iteration:  1500 	 Acc Rate:  86.0 %
# Iteration:  1600 	 Acc Rate:  78.0 %
# Iteration:  1700 	 Acc Rate:  97.0 %
# Iteration:  1800 	 Acc Rate:  79.0 %
# Iteration:  1900 	 Acc Rate:  89.0 %
# Iteration:  2000 	 Acc Rate:  89.0 %
# Iteration:  2100 	 Acc Rate:  70.0 %
# Iteration:  2200 	 Acc Rate:  84.0 %
# Iteration:  2300 	 Acc Rate:  72.0 %
# Iteration:  2400 	 Acc Rate:  86.0 %
# Iteration:  2500 	 Acc Rate:  92.0 %
# Iteration:  2600 	 Acc Rate:  80.0 %
# Iteration:  2700 	 Acc Rate:  72.0 %
# Iteration:  2800 	 Acc Rate:  98.0 %
# Iteration:  2900 	 Acc Rate:  92.0 %
# Iteration:  3000 	 Acc Rate:  89.0 %
# Iteration:  3100 	 Acc Rate:  89.0 %
# Iteration:  3200 	 Acc Rate:  83.0 %
# Iteration:  3300 	 Acc Rate:  92.0 %
# Iteration:  3400 	 Acc Rate:  83.0 %
# Iteration:  3500 	 Acc Rate:  88.0 %
# Iteration:  3600 	 Acc Rate:  77.0 %
# Iteration:  3700 	 Acc Rate:  87.0 %
# Iteration:  3800 	 Acc Rate:  73.0 %
# Iteration:  3900 	 Acc Rate:  77.0 %
# Iteration:  4000 	 Acc Rate:  80.0 %
# Iteration:  4100 	 Acc Rate:  92.0 %
# Iteration:  4200 	 Acc Rate:  73.0 %
# Iteration:  4300 	 Acc Rate:  91.0 %
# Iteration:  4400 	 Acc Rate:  90.0 %
# Iteration:  4500 	 Acc Rate:  77.0 %
# Iteration:  4600 	 Acc Rate:  75.0 %
# Iteration:  4700 	 Acc Rate:  73.0 %
# Iteration:  4800 	 Acc Rate:  69.0 %
# Iteration:  4900 	 Acc Rate:  97.0 %
# Iteration:  5000 	 Acc Rate:  85.0 %
# Iteration:  5100 	 Acc Rate:  67.0 %
# Iteration:  5200 	 Acc Rate:  79.0 %
# Iteration:  5300 	 Acc Rate:  89.0 %
# Iteration:  5400 	 Acc Rate:  98.0 %
# Iteration:  5500 	 Acc Rate:  93.0 %
# Iteration:  5600 	 Acc Rate:  88.0 %
# Iteration:  5700 	 Acc Rate:  78.0 %
# Iteration:  5800 	 Acc Rate:  75.0 %
# Iteration:  5900 	 Acc Rate:  93.0 %
# Iteration:  6000 	 Acc Rate:  93.0 %
# Iteration:  6100 	 Acc Rate:  90.0 %
# Iteration:  6200 	 Acc Rate:  73.0 %
# Iteration:  6300 	 Acc Rate:  80.0 %
# Iteration:  6400 	 Acc Rate:  90.0 %
# Iteration:  6500 	 Acc Rate:  91.0 %
# Iteration:  6600 	 Acc Rate:  66.0 %
# Iteration:  6700 	 Acc Rate:  91.0 %
# Iteration:  6800 	 Acc Rate:  81.0 %
# Iteration:  6900 	 Acc Rate:  59.0 %
# Iteration:  7000 	 Acc Rate:  75.0 %
# Iteration:  7100 	 Acc Rate:  66.0 %
# Iteration:  7200 	 Acc Rate:  68.0 %
# Iteration:  7300 	 Acc Rate:  80.0 %
# Iteration:  7400 	 Acc Rate:  58.0 %
# Iteration:  7500 	 Acc Rate:  81.0 %
# Iteration:  7600 	 Acc Rate:  89.0 %
# Iteration:  7700 	 Acc Rate:  75.0 %
# Iteration:  7800 	 Acc Rate:  76.0 %
# Iteration:  7900 	 Acc Rate:  76.0 %
# Iteration:  8000 	 Acc Rate:  87.0 %
# Iteration:  8100 	 Acc Rate:  86.0 %
# Iteration:  8200 	 Acc Rate:  88.0 %
# Iteration:  8300 	 Acc Rate:  89.0 %
# Iteration:  8400 	 Acc Rate:  80.0 %
# Iteration:  8500 	 Acc Rate:  67.0 %
# Iteration:  8600 	 Acc Rate:  81.0 %
# Iteration:  8700 	 Acc Rate:  73.0 %
# Iteration:  8800 	 Acc Rate:  88.0 %
# Iteration:  8900 	 Acc Rate:  85.0 %
# Iteration:  9000 	 Acc Rate:  87.0 %
# Iteration:  9100 	 Acc Rate:  95.0 %
# Iteration:  9200 	 Acc Rate:  98.0 %
# Iteration:  9300 	 Acc Rate:  68.0 %
# Iteration:  9400 	 Acc Rate:  72.0 %
# Iteration:  9500 	 Acc Rate:  81.0 %
# Iteration:  9600 	 Acc Rate:  92.0 %
# Iteration:  9700 	 Acc Rate:  100.0 %
# Iteration:  9800 	 Acc Rate:  88.0 %
# Iteration:  9900 	 Acc Rate:  83.0 %
# Iteration:  10000 	 Acc Rate:  64.0 %

# %%
next_state, next_duel, meanexp, max_exp_imp = Aq.EUI(iter_num, trial_num, savefig)

# %% [markdown]
# ## Step 3 is the most important step. It outputs next state.

# %% [markdown]
# # next_state ?

# %%
next_state
# Out:
# array([27.])

# %% [markdown]
# # next duel ?
#
# One of the state is always shared between two duels. So, this is nothing but concatenation of next_state with previous.

# %%
next_duel
# Out:
# array([26.72, 27.  ])

# %% [markdown]
# # max EUI ?

# %%
max_exp_imp
# Out:
# 0.00010634877671127916

# %% [markdown]
# # Step 4 (Sanity checks)
#
# Is our framework on the right track?
#
# Check -
# 1. Max Expected Improvement value (is it less than the previous iteration's expected improvement? If so, GOOD!
# 2. Check the Expected Improvement plots. This will be saved automatically in '../data/results/T1/exp_imp_plots/iteration_num'.
# 3. Also check utility samples, how they look? Do they make sense? Is our framework going towards max? Some utility samples will also be saved in '../data/results/T1/utility_samples/iteration_num'.

# %% [markdown]
# # Step 5
#
# 1. Once you have verified that the framework is on the right track, change the operating temp of the room to the next_state as above.
# 2. Its fine if you are not able to acheive the next state accurately, just record the measured next state value.
# 2. Ask the occupant again, which state does he prefer.
# 3. Add the new measured state and response to the csv  '../data/duels/duels.csv' file.
# 4. Add max_exp_imp to the MEUI column.
# 5. Run the notebook again with updated csv file.
# 6. As you progress with the elicitation, you will notice that the ratio $(MEUI_{(i+1)} - MEUI_{(i)})/MEUI_{(i)}$ will decrease. Based on pilot study, stop the elicitation, once the ratio becomes small enough.

# %%
V = datagen.ThermalPrefDataGen(config_file)
Ynew = V.response_gen1D(next_duel[:,None].T)
Ynew
# Out:
# array([0])

# %%
Aq.m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>unimodal_model.Vf</td><td>[[-0.13037151]</br> [ 1.66344327]</br> [ 0.01978395]</br> [-1.40741327]</br> [-0.79585731]</br> [ 0.32326364]</br> [ 0.82577348]</br> [ 0.05791252]</br> [ 0.40251704]</br> [-0.07632558]</br> [-0.55794901]</br> [ 1.22678588]</br> [ 0.29467149]</br> [ 0.04860262]</br> [-2.34074424]</br> [-1.22489821]</br> [ 1.40616248]</br> [ 2.11675189]</br> [-0.32082538]</br> [-0.19463464]</br> [ 0.63460018]</br> [-1.22037349]</br> [ 0.9143508 ]</br> [-0.14650927]</br> [-0.16123842]</br> [ 0.12917618]</br> [ 0.03935801]</br> [-1.21183701]</br> [ 0.10636897]</br> [ 1.34141697]</br> [-1.45074778]</br> [-1.44603345]</br> [ 0.20880967]</br> [ 0.5954014 ]</br> [-0.53178815]</br> [ 2.01642861]</br> [-1.87554928]</br> [-0.29400313]</br> [-0.17760907]</br> [-1.99971304]</br> [ 1.46947524]</br> [ 1.20670228]</br> [ 1.34315212]</br> [ 1.18630881]</br> [ 0.0480528 ]</br> [-0.36000806]</br> [-0.93093731]</br> [ 2.24584091]</br> [-0.5440116 ]</br> [-1.8724699 ]</br> [-0.6117656 ]</br> [-0.7245411 ]</br> [ 1.06228506]</br> [ 0.41061762]</br> [ 2.20376816]</br> [ 0.47069225]]</td><td>N([0.],[1.])</td><td>(none)</td></tr><tr><td>unimodal_model.Vg</td><td>[[ 2.41472756]</br> [-1.0441559 ]</br> [ 0.94804342]</br> [ 0.46007668]</br> [ 0.8725891 ]</br> [-1.05959305]</br> [-0.22825113]</br> [-0.34620475]</br> [ 0.77659856]</br> [ 0.41601335]</br> [-1.6965917 ]</br> [-0.55192229]</br> [ 0.13285877]</br> [-0.34397661]</br> [ 1.05313625]</br> [ 1.35074994]</br> [-0.25088036]</br> [-0.33845781]</br> [-1.80105761]</br> [ 1.42530245]</br> [ 0.57468349]</br> [ 1.18966308]</br> [-1.70881704]</br> [ 0.37699461]</br> [-1.21244929]</br> [ 1.03167677]</br> [ 0.86037766]</br> [-1.12997863]</br> [ 1.7242437 ]</br> [-1.76018165]</br> [ 1.0821653 ]</br> [-1.23417724]</br> [-0.98837113]</br> [ 0.31241431]</br> [ 0.45464027]</br> [ 0.51031946]</br> [-0.24289966]</br> [ 1.54643137]</br> [-0.41349591]</br> [ 1.44451595]</br> [ 1.34465544]</br> [-0.50885373]</br> [-0.91649874]</br> [-0.13689103]</br> [ 1.38375966]</br> [-0.63517989]</br> [ 1.11308504]</br> [ 0.4436014 ]</br> [ 1.52931039]</br> [-0.13504979]</br> [-1.5326521 ]</br> [ 0.45666553]</br> [ 0.16307963]</br> [-0.12551402]</br> [-0.17146304]</br> [ 1.03392978]</br> [-0.49409281]</br> [-0.34310968]</br> [-0.66409202]</br> [ 0.83681562]</br> [ 0.5746674 ]</br> [-1.4445476 ]</br> [ 0.00316584]</br> [-1.1949122 ]</br> [ 0.48643941]</br> [ 1.07680312]</br> [ 0.03142182]</br> [ 0.17155021]</br> [-0.27373715]</br> [ 1.26129315]</br> [-0.99818784]</br> [-1.40014461]</br> [-1.10952269]</br> [-1.78812587]</br> [ 1.29601106]</br> [ 0.31131794]</br> [-0.95040332]</br> [ 0.82884287]</br> [-0.96522823]</br> [ 0.69995   ]]</td><td>N([0.],[1.])</td><td>(none)</td></tr><tr><td>unimodal_model.kern_f.lengthscale</td><td>[1.16066032]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>unimodal_model.kern_f.signal_variance</td><td>[3.14518646]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>unimodal_model.kern_g.lengthscale</td><td>[2.19780656]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>unimodal_model.kern_g.signal_variance</td><td>[2.57576267]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr></table>

# %%
model = Aq.m
samples = Aq.samples

# %%
sample_df = model.get_samples_df(samples)

# %%
xnew = np.linspace(20,27,20)[:,None]
xx = V.normalize1D(xnew)
meanmat = np.zeros(shape = (samples.shape[0], xx.shape[0]))
varmat = np.zeros(shape = (samples.shape[0], xx.shape[0]))
for i, s in sample_df.iterrows():
    model.set_parameter_dict(s)
    mean, v = model.predict_f(xx)
    var = v[:,:,0]
    meanmat[i,:] = mean[:,0]
    varmat[i,:] = np.diag(var)

# %%
def visualize_utility(Xgrid, Mgrid, Vargrid):
    """
    Visualize 1D utility funciton values
    Xgrid : grid states
    Mgrid : mean of GP at those finite grid points
    Vargrid : variance of GP at those finite grid points
    """
    Stdgrid = np.sqrt(Vargrid)
    lower = Mgrid - 2*Stdgrid
    upper = Mgrid + 2*Stdgrid
    #plt.figure(figsize=(12,8))
    #plt.plot(Xgrid[:,0], lower, 'g')
    #plt.plot(Xgrid[:,0], upper, 'r')
    #plt.plot(Xgrid[:,0], Mgrid, 'b')
    
    line, = plt.plot(Xgrid, Mgrid, lw = 2, color = 'b', label = 'utility', alpha = 0.5)
    plt.fill_between(Xgrid[:,0], lower, upper,
                     color = line.get_color(), alpha = 0.25)
    plt.xlabel('Temperature degC')
    plt.ylabel('Utility')
    plt.title('Utility at different temp values')
    return

# %%
mini = 4000
maxi = 4010
plt.figure(figsize=(12,8))
for i in xrange(mini,maxi):
    visualize_utility(xnew, meanmat[i,:], varmat[i,:])
#plt.legend(loc = 'best')

# %%
model
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>unimodal_model.Vf</td><td>[[ 0.07191329]</br> [ 0.56493504]</br> [ 0.71138173]</br> [-0.57459869]</br> [-0.33076643]</br> [-0.15083092]</br> [-0.74121798]</br> [ 0.24091135]</br> [ 0.1564921 ]</br> [-1.35218891]</br> [ 0.78833458]</br> [-0.49849788]</br> [-0.10348677]</br> [-0.21112335]</br> [ 0.40140374]</br> [ 0.00997761]</br> [-0.52988767]</br> [ 0.37148475]</br> [ 0.14087826]</br> [ 1.79324866]</br> [ 0.40520458]</br> [-0.70803662]</br> [-0.24530728]</br> [-0.69357515]</br> [ 0.34360367]</br> [-0.36858984]</br> [-0.25718221]</br> [ 0.26678343]</br> [ 1.07100659]</br> [ 1.03394769]</br> [-0.05647148]</br> [ 0.46895522]</br> [-1.78519249]</br> [ 2.03118336]</br> [-0.07671168]</br> [ 0.27715955]</br> [ 0.25608012]</br> [-0.58546171]</br> [ 1.44277671]</br> [ 0.7955634 ]</br> [ 1.30623958]</br> [ 0.19800108]</br> [ 0.09395301]</br> [-0.01901281]</br> [-0.75389169]</br> [ 1.42394714]</br> [-1.46842994]</br> [-0.93021512]</br> [-0.67789817]</br> [-2.11732692]</br> [ 1.26072037]</br> [ 0.40291552]</br> [ 0.45706886]</br> [-0.72305942]</br> [ 0.19099773]</br> [ 0.33736387]]</td><td>N([0.],[1.])</td><td>(none)</td></tr><tr><td>unimodal_model.Vg</td><td>[[ 1.89794241]</br> [-0.15625923]</br> [-0.68146009]</br> [-0.40838166]</br> [ 0.64605808]</br> [-0.36609422]</br> [ 0.4436369 ]</br> [-0.38469235]</br> [-1.97468216]</br> [-0.83126366]</br> [ 0.88450809]</br> [-0.75281245]</br> [-0.46305882]</br> [ 0.07913037]</br> [ 2.51944801]</br> [-0.18909369]</br> [-0.05602399]</br> [-0.01500513]</br> [-1.55732708]</br> [ 0.19746487]</br> [ 0.53465789]</br> [-0.38140032]</br> [-0.50829727]</br> [ 0.14398959]</br> [ 0.52077188]</br> [ 0.58387051]</br> [-0.77412846]</br> [-0.51336196]</br> [-0.38908242]</br> [ 0.0718821 ]</br> [ 0.40549229]</br> [ 1.41923672]</br> [-0.22811225]</br> [ 0.07766772]</br> [ 0.32318364]</br> [ 0.16022181]</br> [-0.1035778 ]</br> [-0.05582025]</br> [ 0.94139037]</br> [-1.43535925]</br> [ 2.59046372]</br> [ 1.0562805 ]</br> [-0.86163182]</br> [ 1.06509677]</br> [ 0.37419888]</br> [-0.76393186]</br> [-0.4307176 ]</br> [ 1.47106364]</br> [-0.94842513]</br> [ 0.82591046]</br> [-0.16288961]</br> [-0.22972065]</br> [-0.24769505]</br> [ 1.01857363]</br> [ 0.86194865]</br> [-0.35632632]</br> [ 0.66364655]</br> [ 0.14301453]</br> [-0.65110403]</br> [-0.9926055 ]</br> [ 0.40719212]</br> [ 0.55539377]</br> [ 0.04367282]</br> [-0.7547935 ]</br> [-0.6969779 ]</br> [-1.10884748]</br> [-2.24872816]</br> [ 0.91834999]</br> [-0.37886599]</br> [-1.16302433]</br> [ 1.45858482]</br> [ 1.09219311]</br> [-0.51101014]</br> [ 0.63719087]</br> [ 0.63589231]</br> [ 0.9995781 ]</br> [-2.19634355]</br> [-1.22466874]</br> [ 0.3894036 ]</br> [-0.69864918]]</td><td>N([0.],[1.])</td><td>(none)</td></tr><tr><td>unimodal_model.kern_f.lengthscale</td><td>[1.89323927]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>unimodal_model.kern_f.signal_variance</td><td>[1.08986911]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>unimodal_model.kern_g.lengthscale</td><td>[2.9839194]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>unimodal_model.kern_g.signal_variance</td><td>[0.87481985]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr></table>

# %%
from scipy.stats import norm
def diff_norm_g(m, samples, Xgridnorm, Xgrid, mini, maxi):
    """
    Different utilities along with the associated uncertainities
    """
    plt.figure(figsize=(12,8))
    for i in xrange(mini,maxi):
        m.set_state(samples[i,:])
        g = m.predict_g_samples(Xgridnorm, 1)
        plt.plot(Xgrid, norm.cdf(g[0,:,:]), 'b', lw=2, alpha = 0.25)
    a = np.linspace(19.8, 27.2, 100)
    plt.plot(a, 0.5*np.ones(a.shape[0]), 'k')
    plt.xlim(19.8,27.2)
    plt.xlabel('Temperature degC')
    plt.ylabel('Indicator')
    plt.title('Indicator at different temp values')

# %%
diff_norm_g(model, samples, xx, xnew, 4800, 5000)

# %%
from scipy.stats import norm
def diff_g(m, samples, Xgridnorm, Xgrid, mini, maxi):
    """
    Different utilities along with the associated uncertainities
    """
    plt.figure(figsize=(12,8))
    for i in xrange(mini,maxi):
        m.set_state(samples[i,:])
        g = m.predict_g_samples(Xgridnorm, 1)
        plt.plot(Xgrid, g[0,:,:], 'b', lw=2, alpha = 0.25)
    a = np.linspace(19.8, 27.2, 100)
    plt.plot(a, np.zeros(a.shape[0]), 'k')
    plt.xlabel('Temperature degC')
    plt.ylabel('Latent g')
    plt.title('Latent g at different temp values')
    plt.xlim(19.8,27.2)

# %%
diff_g(model, samples, xx, xnew, 0, 4500)

# %%
model.set_state(samples[2])
model
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>unimodal_model.Vf</td><td>[[-0.32601609]</br> [ 0.99399638]</br> [ 1.32302205]</br> [-0.17420894]</br> [ 0.34195399]</br> [ 2.363659  ]</br> [ 0.08409556]</br> [-0.80271629]</br> [ 1.36689648]</br> [-1.64427715]</br> [-0.62888719]</br> [-0.29899274]</br> [-1.4648804 ]</br> [ 2.16921342]</br> [-1.286173  ]</br> [-1.53206833]</br> [-3.17337706]</br> [-0.44706866]</br> [ 0.66388006]</br> [ 0.0532013 ]</br> [-0.23718666]</br> [ 1.10882325]</br> [ 1.31773418]</br> [-0.92387483]</br> [ 0.91204847]</br> [ 1.2876865 ]</br> [ 1.55748426]</br> [-0.49143127]</br> [-0.0713066 ]</br> [ 0.27537254]</br> [ 0.08568324]</br> [ 0.17243712]</br> [-0.70299961]</br> [ 0.16886118]</br> [-1.44506936]</br> [ 0.15317369]</br> [-0.30083846]</br> [-2.76146746]</br> [-1.3144758 ]</br> [-0.00862456]</br> [ 1.46129464]</br> [ 0.03889132]</br> [ 0.96463533]</br> [ 1.71150422]</br> [-0.27140704]</br> [ 0.12846946]</br> [-0.36802898]</br> [-0.93317976]</br> [-1.08546224]</br> [ 0.42936961]</br> [ 0.10874454]</br> [-2.34073757]</br> [ 1.51144349]</br> [-0.12912742]</br> [-1.55515604]</br> [-1.03680468]]</td><td>N([0.],[1.])</td><td>(none)</td></tr><tr><td>unimodal_model.Vg</td><td>[[ 1.36738414]</br> [-0.42263378]</br> [ 0.69675004]</br> [ 0.00706907]</br> [-0.01005913]</br> [ 0.67655826]</br> [ 0.10473754]</br> [-0.11511902]</br> [-1.73407713]</br> [-1.09716549]</br> [ 0.06952553]</br> [ 0.39458995]</br> [ 0.75483691]</br> [ 1.92855186]</br> [ 0.9828014 ]</br> [ 0.31424219]</br> [-0.12228275]</br> [-0.6350225 ]</br> [-0.93759062]</br> [ 0.31515562]</br> [-1.35735744]</br> [-1.13516968]</br> [ 0.98104532]</br> [ 0.12269671]</br> [-0.46088957]</br> [-1.03678444]</br> [ 2.11182052]</br> [ 0.27054851]</br> [-0.79421016]</br> [ 1.4907398 ]</br> [ 0.86591226]</br> [-0.04358288]</br> [ 0.00521799]</br> [-0.9887233 ]</br> [-0.64493842]</br> [-1.30503713]</br> [ 1.23686366]</br> [-0.10441712]</br> [-0.66352165]</br> [-0.17071349]</br> [ 1.14378621]</br> [-0.64858576]</br> [-1.29056027]</br> [-0.49574817]</br> [ 0.09273584]</br> [-2.30295111]</br> [ 0.3753607 ]</br> [ 0.16168272]</br> [ 1.02851929]</br> [ 1.32459828]</br> [-0.20916503]</br> [ 0.35558033]</br> [-0.12962901]</br> [ 0.76863102]</br> [ 0.04228702]</br> [-1.08350126]</br> [-1.27634484]</br> [-0.28249107]</br> [-1.66467638]</br> [ 0.35324   ]</br> [ 0.80733555]</br> [-2.3746851 ]</br> [-0.77227534]</br> [ 0.12419964]</br> [ 1.55311424]</br> [-1.08598176]</br> [ 1.07957985]</br> [-1.20543234]</br> [-1.19634407]</br> [ 0.30416456]</br> [-1.19619894]</br> [ 0.78459369]</br> [ 0.1532576 ]</br> [-1.84067164]</br> [-0.24992514]</br> [ 0.47012624]</br> [-0.56508426]</br> [-0.98831259]</br> [-0.40032032]</br> [-1.19857229]]</td><td>N([0.],[1.])</td><td>(none)</td></tr><tr><td>unimodal_model.kern_f.lengthscale</td><td>[2.85377358]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>unimodal_model.kern_f.signal_variance</td><td>[1.96747538]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>unimodal_model.kern_g.lengthscale</td><td>[1.68023171]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>unimodal_model.kern_g.signal_variance</td><td>[2.32493815]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr></table>

# %%
sample_df = model.get_samples_df(samples)
sample_df.head()
# Out:
#                                    unimodal_model.Vf  \
# 0  [[-0.1710292982233469], [1.1291793251072317], ...
# 1  [[-0.28384999006680456], [1.00613218442922], [...
# 2  [[-0.326016091273674], [0.9939963773106859], [...
# 3  [[-0.4128300507589842], [0.8177668997302135], ...
# 4  [[-0.5512755323591811], [0.8342262031073094], ...
#
#                                    unimodal_model.Vg  \
# 0  [[1.5269468186227706], [-0.22749606713867498],...
# 1  [[1.6225726843312376], [-0.36977904469093614],...
# 2  [[1.3673841385203873], [-0.4226337831608814], ...
# 3  [[1.537835704276163], [-0.3415817025881012], [...
# 4  [[1.4534900220790719], [-0.23552973663037677],...
#
#   unimodal_model.kern_f.lengthscale unimodal_model.kern_f.signal_variance  \
# 0              [2.7063721665423865]                   [2.213317201563097]
# 1              [2.7164211625071686]                   [2.086272394825296]
# 2              [2.8537735762638996]                  [1.9674753784977848]
# 3              [2.8977996263663837]                  [1.7548658956061554]
# 4              [3.0456480719839387]                  [1.8875872608785782]
#
#   unimodal_model.kern_g.lengthscale unimodal_model.kern_g.signal_variance
# 0              [2.1556235164352113]                  [2.2571406554132025]
# 1              [1.9569700211453793]                   [2.120778087790026]
# 2              [1.6802317123521089]                  [2.3249381502990714]
# 3              [1.8397939125232314]                   [2.513928527211903]
# 4              [1.9580864446146378]                   [2.589508022005809]

# %%
plt.plot(samples[:,-4])

# %%
plt.figure(figsize=(12,8))
plt.plot(sample_df['unimodal_model.kern_f.lengthscale'],
            sample_df['unimodal_model.kern_f.signal_variance'], 'k.', alpha = 0.15)
plt.xlabel('signal_lengthscale')
plt.ylabel('signal_variance')
# Out:
# Text(0,0.5,u'signal_variance')

# %%
samples.shape
# Out:
# (5000, 50)
