# %% [markdown]
# # Thermal Preference Elicitation Framework
#
# Currently, this framework has been validated for only 1D (operating temp) feature./

# %% [markdown]
# # Step 1
#
# Load required modules

# %%
import sys
sys.path.append('../')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy
sns.set_context("talk", font_scale = 1.4)
from GPFlowUnimodalPref.GPUnimodalElicit import elicit
from GPFlowUnimodalPref.SynOccupant import datagen
# Out:
# /Users/nimishawalgaonkar/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# # Step 2
#
# 1. Occupant walks inside the room and is exposed to state r.
# 2. Randomly change the state of the room to new state s.
# 3. Ask the occupant which state they prefer.
# 4. If they say state current state s, then record y as 1. If they say previous state r, then record y as 0.
# This first duel is our initial duel.
# 5. Put the duel value and response in the '../data/duels/duels.csv' file

# %%
# Load the duels file
data_file = '../GPFlowUnimodalPref/data/initial_duels/train1D.npz' # <--- you need to keep on updating this file

# %%
data = np.load(data_file)
X = data['X']
Y = data['Y']

# %%
iter_num = X.shape[0]

# %%
#Tprev = np.array(data.Tprev) # previous state (operating temp.)
#Tcurrent = np.array(data.Tcurrent) # current state <---- elicitation framework will give you this values
#X = np.vstack([[Tprev, Tcurrent]]).T
#X = X.astype(float) # features need to be float
X_prime = np.linspace(20, 30, 40)[:,None]
#Y = np.array(data.y)[:,None] # response of the occupant <---- you need to ask occupant about this

# %% [markdown]
# # Step 3
#
# Now, we want to find the next elicited state. So, we need to use **elicit** module.

# %%
config_file = '../GPFlowUnimodalPref/config_files/thermal_config.json' # configuration for grid (how fine you want to be)
trial_num = 10 # this is just to save all the plots in '../data/results/T1' if trial_num = 1 ; T2 if trial_num = 2
model_num = 1
mcmc = True
reachable = True
savefig = True

# %%
Aq =  elicit.IntegratedAquisition(X, Y, X_prime, config_file, model_num, mcmc, reachable)
# Out:
# ----------------------------------------
# Model is 1
# burn-in sampling started
# Iteration:  100 	 Acc Rate:  65.0 %
# Iteration:  200 	 Acc Rate:  66.0 %
# Iteration:  300 	 Acc Rate:  64.0 %
# Iteration:  400 	 Acc Rate:  66.0 %
# Iteration:  500 	 Acc Rate:  51.0 %
# Iteration:  600 	 Acc Rate:  64.0 %
# Iteration:  700 	 Acc Rate:  66.0 %
# Iteration:  800 	 Acc Rate:  66.0 %
# Iteration:  900 	 Acc Rate:  55.0 %
# Iteration:  1000 	 Acc Rate:  48.0 %
# Iteration:  1100 	 Acc Rate:  41.0 %
# Iteration:  1200 	 Acc Rate:  79.0 %
# Iteration:  1300 	 Acc Rate:  60.0 %
# Iteration:  1400 	 Acc Rate:  66.0 %
# Iteration:  1500 	 Acc Rate:  72.0 %
# Iteration:  1600 	 Acc Rate:  61.0 %
# Iteration:  1700 	 Acc Rate:  52.0 %
# Iteration:  1800 	 Acc Rate:  64.0 %
# Iteration:  1900 	 Acc Rate:  25.0 %
# Iteration:  2000 	 Acc Rate:  55.0 %
# Iteration:  2100 	 Acc Rate:  49.0 %
# Iteration:  2200 	 Acc Rate:  53.0 %
# Iteration:  2300 	 Acc Rate:  72.0 %
# Iteration:  2400 	 Acc Rate:  62.0 %
# Iteration:  2500 	 Acc Rate:  62.0 %
# Iteration:  2600 	 Acc Rate:  56.0 %
# Iteration:  2700 	 Acc Rate:  62.0 %
# Iteration:  2800 	 Acc Rate:  65.0 %
# Iteration:  2900 	 Acc Rate:  74.0 %
# Iteration:  3000 	 Acc Rate:  80.0 %
# burn-in sampling ended
# Iteration:  100 	 Acc Rate:  51.0 %
# Iteration:  200 	 Acc Rate:  69.0 %
# Iteration:  300 	 Acc Rate:  32.0 %
# Iteration:  400 	 Acc Rate:  56.0 %
# Iteration:  500 	 Acc Rate:  56.0 %
# Iteration:  600 	 Acc Rate:  57.0 %
# Iteration:  700 	 Acc Rate:  58.0 %
# Iteration:  800 	 Acc Rate:  46.0 %
# Iteration:  900 	 Acc Rate:  56.0 %
# Iteration:  1000 	 Acc Rate:  58.0 %
# Iteration:  1100 	 Acc Rate:  61.0 %
# Iteration:  1200 	 Acc Rate:  41.0 %
# Iteration:  1300 	 Acc Rate:  34.0 %
# Iteration:  1400 	 Acc Rate:  42.0 %
# Iteration:  1500 	 Acc Rate:  20.0 %
# Iteration:  1600 	 Acc Rate:  44.0 %
# Iteration:  1700 	 Acc Rate:  23.0 %
# Iteration:  1800 	 Acc Rate:  46.0 %
# Iteration:  1900 	 Acc Rate:  56.0 %
# Iteration:  2000 	 Acc Rate:  39.0 %
# Iteration:  2100 	 Acc Rate:  59.0 %
# Iteration:  2200 	 Acc Rate:  69.0 %
# Iteration:  2300 	 Acc Rate:  68.0 %
# Iteration:  2400 	 Acc Rate:  53.0 %
# Iteration:  2500 	 Acc Rate:  42.0 %
# Iteration:  2600 	 Acc Rate:  30.0 %
# Iteration:  2700 	 Acc Rate:  33.0 %
# Iteration:  2800 	 Acc Rate:  43.0 %
# Iteration:  2900 	 Acc Rate:  76.0 %
# Iteration:  3000 	 Acc Rate:  48.0 %
# Iteration:  3100 	 Acc Rate:  66.0 %
# Iteration:  3200 	 Acc Rate:  81.0 %
# Iteration:  3300 	 Acc Rate:  64.0 %
# Iteration:  3400 	 Acc Rate:  50.0 %
# Iteration:  3500 	 Acc Rate:  49.0 %
# Iteration:  3600 	 Acc Rate:  75.0 %
# Iteration:  3700 	 Acc Rate:  63.0 %
# Iteration:  3800 	 Acc Rate:  72.0 %
# Iteration:  3900 	 Acc Rate:  47.0 %
# Iteration:  4000 	 Acc Rate:  77.0 %
# Iteration:  4100 	 Acc Rate:  75.0 %
# Iteration:  4200 	 Acc Rate:  78.0 %
# Iteration:  4300 	 Acc Rate:  39.0 %
# Iteration:  4400 	 Acc Rate:  53.0 %
# Iteration:  4500 	 Acc Rate:  46.0 %
# Iteration:  4600 	 Acc Rate:  35.0 %
# Iteration:  4700 	 Acc Rate:  33.0 %
# Iteration:  4800 	 Acc Rate:  31.0 %
# Iteration:  4900 	 Acc Rate:  50.0 %
# Iteration:  5000 	 Acc Rate:  60.0 %
# Iteration:  5100 	 Acc Rate:  43.0 %
# Iteration:  5200 	 Acc Rate:  61.0 %
# Iteration:  5300 	 Acc Rate:  53.0 %
# Iteration:  5400 	 Acc Rate:  59.0 %
# Iteration:  5500 	 Acc Rate:  63.0 %
# Iteration:  5600 	 Acc Rate:  65.0 %
# Iteration:  5700 	 Acc Rate:  63.0 %
# Iteration:  5800 	 Acc Rate:  37.0 %
# Iteration:  5900 	 Acc Rate:  38.0 %
# Iteration:  6000 	 Acc Rate:  54.0 %
# Iteration:  6100 	 Acc Rate:  80.0 %
# Iteration:  6200 	 Acc Rate:  69.0 %
# Iteration:  6300 	 Acc Rate:  66.0 %
# Iteration:  6400 	 Acc Rate:  53.0 %
# Iteration:  6500 	 Acc Rate:  50.0 %
# Iteration:  6600 	 Acc Rate:  51.0 %
# Iteration:  6700 	 Acc Rate:  56.0 %
# Iteration:  6800 	 Acc Rate:  75.0 %
# Iteration:  6900 	 Acc Rate:  65.0 %
# Iteration:  7000 	 Acc Rate:  48.0 %
# Iteration:  7100 	 Acc Rate:  57.0 %
# Iteration:  7200 	 Acc Rate:  50.0 %
# Iteration:  7300 	 Acc Rate:  62.0 %
# Iteration:  7400 	 Acc Rate:  72.0 %
# Iteration:  7500 	 Acc Rate:  54.0 %
# Iteration:  7600 	 Acc Rate:  71.0 %
# Iteration:  7700 	 Acc Rate:  32.0 %
# Iteration:  7800 	 Acc Rate:  62.0 %
# Iteration:  7900 	 Acc Rate:  56.0 %
# Iteration:  8000 	 Acc Rate:  49.0 %
# Iteration:  8100 	 Acc Rate:  57.0 %
# Iteration:  8200 	 Acc Rate:  65.0 %
# Iteration:  8300 	 Acc Rate:  78.0 %
# Iteration:  8400 	 Acc Rate:  81.0 %
# Iteration:  8500 	 Acc Rate:  74.0 %
# Iteration:  8600 	 Acc Rate:  77.0 %
# Iteration:  8700 	 Acc Rate:  49.0 %
# Iteration:  8800 	 Acc Rate:  68.0 %
# Iteration:  8900 	 Acc Rate:  52.0 %
# Iteration:  9000 	 Acc Rate:  55.0 %
# Iteration:  9100 	 Acc Rate:  62.0 %
# Iteration:  9200 	 Acc Rate:  60.0 %
# Iteration:  9300 	 Acc Rate:  46.0 %
# Iteration:  9400 	 Acc Rate:  49.0 %
# Iteration:  9500 	 Acc Rate:  37.0 %
# Iteration:  9600 	 Acc Rate:  47.0 %
# Iteration:  9700 	 Acc Rate:  35.0 %
# Iteration:  9800 	 Acc Rate:  32.0 %
# Iteration:  9900 	 Acc Rate:  49.0 %
# Iteration:  10000 	 Acc Rate:  44.0 %

# %%
next_state, next_duel, meanexp, max_exp_imp = Aq.EUI(iter_num, trial_num, savefig)

# %% [markdown]
# ## Step 3 is the most important step. It outputs next state.

# %% [markdown]
# # next_state ?

# %%
next_state
# Out:
# array([23.])

# %% [markdown]
# # next duel ?
#
# One of the state is always shared between two duels. So, this is nothing but concatenation of next_state with previous.

# %%
next_duel
# Out:
# array([23., 23.])

# %% [markdown]
# # max EUI ?

# %%
max_exp_imp
# Out:
# 9.99100660361714e-06

# %% [markdown]
# # Step 4 (Sanity checks)
#
# Is our framework on the right track?
#
# Check -
# 1. Max Expected Improvement value (is it less than the previous iteration's expected improvement? If so, GOOD!
# 2. Check the Expected Improvement plots. This will be saved automatically in '../data/results/T1/exp_imp_plots/iteration_num'.
# 3. Also check utility samples, how they look? Do they make sense? Is our framework going towards max? Some utility samples will also be saved in '../data/results/T1/utility_samples/iteration_num'.

# %% [markdown]
# # Step 5
#
# 1. Once you have verified that the framework is on the right track, change the operating temp of the room to the next_state as above.
# 2. Its fine if you are not able to acheive the next state accurately, just record the measured next state value.
# 2. Ask the occupant again, which state does he prefer.
# 3. Add the new measured state and response to the csv  '../data/duels/duels.csv' file.
# 4. Add max_exp_imp to the MEUI column.
# 5. Run the notebook again with updated csv file.
# 6. As you progress with the elicitation, you will notice that the ratio $(MEUI_{(i+1)} - MEUI_{(i)})/MEUI_{(i)}$ will decrease. Based on pilot study, stop the elicitation, once the ratio becomes small enough.

# %%
V = datagen.ThermalPrefDataGen(config_file)
Ynew = V.response_gen1D(next_duel[:,None].T)
Ynew
# Out:
# array([0])

# %%
Aq.m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>unimodal_model.Vf</td><td>[[ 0.67018415]</br> [ 0.96257882]</br> [-1.36027889]</br> [ 3.11113667]</br> [ 1.41675434]</br> [-0.05850636]</br> [ 1.4704711 ]</br> [ 0.60912138]</br> [ 0.27125039]</br> [ 0.31294437]</br> [-0.29723451]</br> [-0.93224307]</br> [ 0.35987822]</br> [ 0.68135761]</br> [-0.34127968]</br> [ 0.15652047]</br> [ 0.64729068]</br> [-0.94294882]</br> [-0.89197322]</br> [ 0.7835921 ]</br> [ 0.05930185]</br> [-0.52087431]</br> [-1.26408884]</br> [ 0.76975728]</br> [-1.41444877]</br> [-0.78921815]</br> [-0.39005869]</br> [ 1.75426721]</br> [ 0.97785076]</br> [ 0.28237121]</br> [-0.58624823]</br> [-0.90013721]</br> [ 0.51308072]</br> [ 0.01452089]</br> [ 0.91195346]</br> [ 0.35480417]</br> [-0.34869509]</br> [-0.16170779]</br> [ 0.23698457]</br> [ 1.08131188]</br> [ 0.95036452]</br> [-1.44594762]</br> [ 2.30768322]</br> [ 1.19881547]</br> [-0.04137636]</br> [ 0.43492181]</br> [ 1.54564444]</br> [ 2.05856976]</br> [ 0.25304807]</br> [-0.67488298]</br> [ 0.10716534]</br> [ 1.09303109]</br> [ 2.44177597]</br> [-0.77839683]</br> [ 2.17156239]</br> [-2.70008907]</br> [ 0.42894729]</br> [ 0.90274924]</br> [-1.44700463]</br> [-0.41468474]</br> [ 2.06131651]</br> [-0.21919654]</br> [-1.07419432]</br> [ 0.11690482]</br> [-0.36786234]</br> [ 0.64107906]</br> [-1.15285955]</br> [-0.68715101]</br> [-1.1555698 ]</br> [ 0.30566796]</br> [-0.57059095]</br> [ 1.25461571]</br> [ 0.165847  ]</br> [-0.25554938]</br> [-0.05020396]</br> [-0.61645912]</br> [-0.195069  ]</br> [ 0.56821375]</br> [ 0.80143757]</br> [-0.41629622]</br> [-0.61204231]</br> [-0.21681405]</br> [ 1.93967331]</br> [-1.40395883]</br> [ 0.13011423]</br> [-0.03707847]</br> [ 0.6692149 ]</br> [ 0.07794384]</br> [-0.22559715]</br> [ 1.62307855]</br> [-0.75728456]</br> [ 1.15236206]</br> [ 1.59838053]</br> [-0.26233554]</br> [-1.86423499]</br> [-0.09281051]</br> [ 1.25158527]</br> [-1.88050581]</br> [-0.69041071]</br> [-0.44240112]</br> [-1.17754761]</br> [-0.89417664]</br> [ 2.98796773]</br> [ 0.1984163 ]</br> [-0.50664116]</br> [ 0.62918433]</br> [ 1.02620543]</br> [-1.81761816]</br> [-2.23091562]</br> [ 0.14072239]</br> [ 0.35922549]</br> [-0.22764958]</br> [ 0.04309874]</br> [-0.73074341]</br> [ 0.73385772]</br> [-0.82450937]</br> [ 1.66592345]</br> [-1.25702864]</br> [-0.19419043]</br> [-0.1506054 ]]</td><td>N([0.],[1.])</td><td>(none)</td></tr><tr><td>unimodal_model.Vg</td><td>[[ 1.63124986]</br> [-2.22611376]</br> [-1.50494039]</br> [ 0.00774884]</br> [ 0.76594465]</br> [-0.88388704]</br> [-0.758794  ]</br> [-1.78269632]</br> [-1.85454007]</br> [ 1.87333864]</br> [-1.653468  ]</br> [ 0.73399756]</br> [-0.30063195]</br> [-0.07330559]</br> [-0.46093534]</br> [-0.36604752]</br> [ 0.30466854]</br> [-1.08059791]</br> [-0.6889121 ]</br> [ 0.26466321]</br> [ 0.2271987 ]</br> [-0.04607085]</br> [ 0.44999505]</br> [-0.61874168]</br> [ 0.01647045]</br> [-1.26544821]</br> [-0.35956719]</br> [-0.00749261]</br> [ 1.59919237]</br> [ 2.26030238]</br> [-1.01527631]</br> [ 0.08516918]</br> [ 0.91737701]</br> [-0.48392489]</br> [ 0.22910845]</br> [ 0.92698607]</br> [ 0.67212937]</br> [ 0.59036223]</br> [ 1.81265915]</br> [-0.16808398]</br> [ 0.14551607]</br> [-1.5255419 ]</br> [-0.25381134]</br> [-1.20956471]</br> [-1.65691265]</br> [-0.40465786]</br> [-1.12420521]</br> [-1.57635011]</br> [ 1.66324785]</br> [ 0.10871643]</br> [-0.57024391]</br> [-0.48743351]</br> [ 0.69355128]</br> [-0.44061984]</br> [ 0.96842529]</br> [-0.30048799]</br> [-0.61640842]</br> [ 0.99063794]</br> [ 0.03505487]</br> [ 0.70911215]</br> [ 0.5270313 ]</br> [ 0.30696735]</br> [-0.28602279]</br> [ 1.76803861]</br> [ 0.8860194 ]</br> [ 0.07719192]</br> [ 0.5991942 ]</br> [ 0.90429982]</br> [ 0.41822089]</br> [-1.30076031]</br> [ 0.55917528]</br> [-0.7763018 ]</br> [ 2.09365053]</br> [-0.50253353]</br> [-0.02691936]</br> [-0.5086197 ]</br> [-0.01768916]</br> [-0.22365734]</br> [ 0.67009471]</br> [ 0.2975 ...

# %%
model = Aq.m
samples = Aq.samples

# %%
sample_df = model.get_samples_df(samples)

# %%
xnew = np.linspace(20,27,20)[:,None]
xx = V.normalize1D(xnew)
meanmat = np.zeros(shape = (samples.shape[0], xx.shape[0]))
varmat = np.zeros(shape = (samples.shape[0], xx.shape[0]))
for i, s in sample_df.iterrows():
    model.set_parameter_dict(s)
    mean, v = model.predict_f(xx)
    var = v[:,:,0]
    meanmat[i,:] = mean[:,0]
    varmat[i,:] = np.diag(var)

# %%
def visualize_utility(Xgrid, Mgrid, Vargrid):
    """
    Visualize 1D utility funciton values
    Xgrid : grid states
    Mgrid : mean of GP at those finite grid points
    Vargrid : variance of GP at those finite grid points
    """
    Stdgrid = np.sqrt(Vargrid)
    lower = Mgrid - 2*Stdgrid
    upper = Mgrid + 2*Stdgrid
    #plt.figure(figsize=(12,8))
    #plt.plot(Xgrid[:,0], lower, 'g')
    #plt.plot(Xgrid[:,0], upper, 'r')
    #plt.plot(Xgrid[:,0], Mgrid, 'b')
    
    line, = plt.plot(Xgrid, Mgrid, lw = 2, color = 'b', label = 'utility', alpha = 0.5)
    plt.fill_between(Xgrid[:,0], lower, upper,
                     color = line.get_color(), alpha = 0.25)
    plt.xlabel('Temperature degC')
    plt.ylabel('Utility')
    plt.title('Utility at different temp values')
    return

# %%
mini = 10
maxi = 60
plt.figure(figsize=(12,8))
for i in xrange(mini,maxi):
    visualize_utility(xnew, meanmat[i,:], varmat[i,:])
#plt.legend(loc = 'best')

# %%
model
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>unimodal_model.Vf</td><td>[[ 0.88977957]</br> [ 1.38053091]</br> [ 0.49194399]</br> [ 4.41321753]</br> [ 0.12879586]</br> [-0.42784336]</br> [ 0.83021477]</br> [-0.5517687 ]</br> [-0.16924245]</br> [ 0.37939251]</br> [ 2.55560244]</br> [-0.02652287]</br> [ 1.041022  ]</br> [ 0.45146542]</br> [-0.11575763]</br> [-2.54357308]</br> [-0.60411718]</br> [-1.1517932 ]</br> [ 0.6026532 ]</br> [ 0.52567729]</br> [-0.33273099]</br> [ 0.23402041]</br> [ 0.71078156]</br> [-0.50923557]</br> [-0.10263689]</br> [ 1.80753776]</br> [-0.70398078]</br> [-1.68442072]</br> [-0.53403017]</br> [-2.85120771]</br> [-0.42708903]</br> [-0.27915813]</br> [ 0.50445191]</br> [-1.15226316]</br> [-0.0293695 ]</br> [ 0.86733752]</br> [ 0.27118517]</br> [-0.13100444]</br> [ 1.15572709]</br> [ 0.14874759]</br> [-0.02568218]</br> [ 0.43780522]</br> [-1.56467743]</br> [ 2.27958639]</br> [ 0.61317843]</br> [ 1.26982194]</br> [-0.6060939 ]</br> [ 0.88122482]</br> [ 1.14044665]</br> [-1.34944868]</br> [ 0.29491148]</br> [ 0.84703772]</br> [ 1.9730038 ]</br> [-1.44051849]</br> [ 0.82589687]</br> [-0.70039683]</br> [-2.37069229]</br> [-0.3670234 ]</br> [-0.1802989 ]</br> [-1.75758665]</br> [-0.11962797]</br> [ 0.89377678]</br> [ 0.79587119]</br> [ 0.4750364 ]</br> [ 0.79269782]</br> [ 0.72957898]</br> [ 0.36569435]</br> [ 0.88284391]</br> [-0.59030296]</br> [-0.59399192]</br> [-0.18928182]</br> [-0.57738335]</br> [-2.14399711]</br> [-0.45915175]</br> [-0.46971343]</br> [-0.40068049]</br> [-1.82098145]</br> [ 0.98674993]</br> [ 0.65737752]</br> [-0.92551073]</br> [-0.01844457]</br> [-0.87934294]</br> [ 1.18509931]</br> [ 1.13088094]</br> [-1.61412772]</br> [-0.47805858]</br> [ 0.3260537 ]</br> [-1.91798068]</br> [-0.03620349]</br> [ 0.41361955]</br> [ 1.02563828]</br> [-0.99051294]</br> [-3.01623349]</br> [-0.57067186]</br> [ 1.62061035]</br> [-0.5449555 ]</br> [-0.65998148]</br> [ 0.56295481]</br> [ 1.56824848]</br> [ 1.38046467]</br> [ 0.60985464]</br> [ 0.16528183]</br> [-0.23384362]</br> [ 0.44072989]</br> [-0.25785935]</br> [-1.77909968]</br> [-1.56408976]</br> [-0.38336039]</br> [-1.22562424]</br> [-0.18902947]</br> [-0.46283662]</br> [-0.59961604]</br> [ 3.23996352]</br> [-0.95127353]</br> [ 0.86954221]</br> [-1.76241842]</br> [-0.47776916]</br> [-2.5011937 ]</br> [-0.79927647]</br> [ 0.0600906 ]]</td><td>N([0.],[1.])</td><td>(none)</td></tr><tr><td>unimodal_model.Vg</td><td>[[ 1.84433054]</br> [-0.22867912]</br> [-0.8808532 ]</br> [-0.58002176]</br> [-0.80015891]</br> [ 0.03144499]</br> [-2.32069566]</br> [-0.58257065]</br> [ 0.35120331]</br> [ 1.61688692]</br> [ 1.03534804]</br> [-1.18586269]</br> [-1.22123315]</br> [ 0.6782945 ]</br> [-0.49327311]</br> [ 1.17892283]</br> [ 0.44318606]</br> [-0.32922981]</br> [-0.44231265]</br> [-1.87417014]</br> [-1.52059726]</br> [-2.10085757]</br> [-0.27660002]</br> [-0.67074252]</br> [-0.48707795]</br> [-1.39715543]</br> [ 0.37786363]</br> [-0.56932338]</br> [-2.61930239]</br> [-0.97876154]</br> [-0.88776567]</br> [-0.63587576]</br> [ 1.0986048 ]</br> [-1.09171379]</br> [ 1.05365393]</br> [-1.10913992]</br> [-0.8926937 ]</br> [-1.65394571]</br> [-0.96955767]</br> [-1.22607663]</br> [-0.24063854]</br> [ 0.33615396]</br> [ 0.69383963]</br> [-1.93992038]</br> [-1.12778932]</br> [-0.46646526]</br> [ 1.35937402]</br> [-0.83919077]</br> [-0.86780193]</br> [ 0.88685505]</br> [-0.22027431]</br> [ 0.81668918]</br> [ 0.3256783 ]</br> [-0.83515897]</br> [-1.15768569]</br> [-1.86313067]</br> [ 1.31448885]</br> [-1.06841123]</br> [-2.64131319]</br> [ 0.0207773 ]</br> [-0.84766243]</br> [ 1.81374005]</br> [ 1.31850426]</br> [-0.68777815]</br> [ 0.53477686]</br> [-2.07285093]</br> [-0.1628279 ]</br> [-0.86234163]</br> [ 0.71588279]</br> [-1.19969043]</br> [-2.03780696]</br> [ 0.29942357]</br> [ 0.93383024]</br> [ 0.77214893]</br> [ 0.09455437]</br> [-0.40223926]</br> [-3.26969129]</br> [-0.65991337]</br> [-1.55355502]</br> [-0.6677 ...

# %%
from scipy.stats import norm
def diff_norm_g(m, samples, Xgridnorm, Xgrid, mini, maxi):
    """
    Different utilities along with the associated uncertainities
    """
    plt.figure(figsize=(12,8))
    for i in xrange(mini,maxi):
        m.set_state(samples[i,:])
        g = m.predict_g_samples(Xgridnorm, 1)
        plt.plot(Xgrid, norm.cdf(g[0,:,:]), 'b', lw=2, alpha = 0.25)
    a = np.linspace(19.8, 27.2, 100)
    plt.plot(a, 0.5*np.ones(a.shape[0]), 'k')
    plt.xlim(19.8,27.2)
    plt.xlabel('Temperature degC')
    plt.ylabel('Indicator')
    plt.title('Indicator at different temp values')

# %%
diff_norm_g(model, samples, xx, xnew, 0, 5000)

# %%
from scipy.stats import norm
def diff_g(m, samples, Xgridnorm, Xgrid, mini, maxi):
    """
    Different utilities along with the associated uncertainities
    """
    plt.figure(figsize=(12,8))
    for i in xrange(mini,maxi):
        m.set_state(samples[i,:])
        g = m.predict_g_samples(Xgridnorm, 1)
        plt.plot(Xgrid, g[0,:,:], 'b', lw=2, alpha = 0.25)
    a = np.linspace(19.8, 27.2, 100)
    plt.plot(a, np.zeros(a.shape[0]), 'k')
    plt.xlabel('Temperature degC')
    plt.ylabel('Latent g')
    plt.title('Latent g at different temp values')
    plt.xlim(19.8,27.2)

# %%
diff_g(model, samples, xx, xnew, 0, 2600)

# %%
model.set_state(samples[2])
model
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>unimodal_model.Vf</td><td>[[ 0.56615597]</br> [ 1.4218049 ]</br> [ 0.19731038]</br> [ 1.88816466]</br> [ 1.30545409]</br> [ 0.82834478]</br> [ 0.47024527]</br> [-1.42986939]</br> [-0.35360505]</br> [-1.55227008]</br> [ 0.21337033]</br> [ 0.75390375]</br> [ 1.02419632]</br> [ 1.02948059]</br> [-1.3805417 ]</br> [ 0.05564199]</br> [ 0.85627712]</br> [-0.11279952]</br> [ 0.25824642]</br> [-0.61945953]</br> [-0.20932375]</br> [-0.73134346]</br> [-1.36394618]</br> [ 0.61022427]</br> [ 0.7043857 ]</br> [-0.16314679]</br> [ 0.17650188]</br> [ 0.97333827]</br> [ 1.14187822]</br> [-0.74086795]</br> [-0.6588552 ]</br> [-0.07971977]</br> [-1.32992205]</br> [ 0.21534179]</br> [-0.07302091]</br> [ 1.26410624]</br> [ 0.41887011]</br> [-1.24223382]</br> [ 1.16995816]</br> [ 1.41574783]</br> [ 0.14794556]</br> [ 0.67485803]</br> [ 0.19020465]</br> [-0.72890348]</br> [ 0.5759125 ]</br> [-1.22584163]</br> [ 1.06721597]</br> [-0.39790078]</br> [-0.47917118]</br> [-1.03000283]</br> [ 0.34473579]</br> [-0.31911892]</br> [ 0.89215227]</br> [-0.57057792]</br> [ 0.86868929]</br> [-0.97985693]</br> [-1.23498345]</br> [-0.19247351]</br> [-0.27510531]</br> [ 0.2828721 ]</br> [ 1.07934759]</br> [ 0.63896234]</br> [-0.7863524 ]</br> [ 2.15672503]</br> [ 0.85722356]</br> [ 0.38224766]</br> [-0.03003581]</br> [ 0.1058257 ]</br> [ 0.41693033]</br> [ 1.09389724]</br> [-1.19647092]</br> [-0.35280862]</br> [-0.85477312]</br> [ 1.86664591]</br> [-0.81768858]</br> [ 1.16227167]</br> [-0.25016156]</br> [ 0.53231028]</br> [ 0.42243654]</br> [-0.78228285]</br> [-1.49294245]</br> [ 0.38839081]</br> [-0.86061655]</br> [-0.0320049 ]</br> [-0.18834125]</br> [ 0.73174361]</br> [ 0.15097929]</br> [ 0.59333769]</br> [-0.36135814]</br> [-0.80348489]</br> [-0.91037335]</br> [ 0.84418102]</br> [ 0.85222015]</br> [ 0.49677633]</br> [-0.30573487]</br> [ 0.95750563]</br> [ 0.15234993]</br> [-1.13346224]</br> [-1.77844534]</br> [-0.23353297]</br> [-0.09658831]</br> [ 0.04535157]</br> [-0.46317897]</br> [ 0.34000672]</br> [ 1.19659339]</br> [-1.05432926]</br> [-0.08065869]</br> [-1.13192775]</br> [-1.56241471]</br> [-0.59871978]</br> [-1.38731048]</br> [ 1.82417941]</br> [ 0.30661991]</br> [-0.35673418]</br> [ 1.07186191]</br> [-1.05060752]</br> [ 1.20245826]</br> [ 0.16237622]</br> [-0.14032365]</br> [-0.26200071]]</td><td>N([0.],[1.])</td><td>(none)</td></tr><tr><td>unimodal_model.Vg</td><td>[[ 2.06232048]</br> [-0.77114028]</br> [-1.48311343]</br> [ 0.70363914]</br> [ 1.20595363]</br> [-1.32536233]</br> [ 0.35089013]</br> [-0.9634688 ]</br> [-1.96327992]</br> [ 0.44482594]</br> [-1.94313071]</br> [ 0.32893183]</br> [-0.38726268]</br> [-0.77292706]</br> [-1.27668358]</br> [ 0.22609371]</br> [-0.77863798]</br> [-1.15706432]</br> [ 0.42226875]</br> [-2.12593045]</br> [-1.89144785]</br> [-1.12971898]</br> [-0.25449614]</br> [-0.3320516 ]</br> [-2.11525147]</br> [ 0.95765104]</br> [ 2.09665354]</br> [-1.20465836]</br> [ 1.10942924]</br> [-1.18012576]</br> [-0.12309951]</br> [-0.98009465]</br> [ 1.76314731]</br> [ 1.62353677]</br> [-0.65007005]</br> [-2.41112084]</br> [-0.37547746]</br> [ 0.88274586]</br> [ 0.10669891]</br> [-1.47657161]</br> [-0.55003838]</br> [-2.18701816]</br> [-1.27438613]</br> [ 0.09046587]</br> [-0.19908579]</br> [-1.01336803]</br> [-0.3487729 ]</br> [ 0.30876413]</br> [-1.33813153]</br> [ 0.16723954]</br> [-0.53109678]</br> [ 0.15471697]</br> [-1.7124121 ]</br> [ 1.61953246]</br> [-1.1559207 ]</br> [ 0.77333352]</br> [-1.34653941]</br> [ 2.17205629]</br> [-0.50159884]</br> [ 1.37338325]</br> [-0.36674161]</br> [ 0.07780803]</br> [ 0.58998671]</br> [ 1.4345734 ]</br> [ 0.09658125]</br> [ 0.11779999]</br> [ 2.26908998]</br> [ 0.68427456]</br> [-0.21979431]</br> [-0.02207343]</br> [ 1.37575548]</br> [ 0.1298153 ]</br> [ 0.14856439]</br> [-1.69204465]</br> [ 1.73993565]</br> [-0.98204909]</br> [-0.53607245]</br> [-0.09020478]</br> [-0.81051521]</br> [ 2.0420 ...

# %%
sample_df = model.get_samples_df(samples)
sample_df.head()
# Out:
#                                    unimodal_model.Vf  \
# 0  [[1.0225039565493164], [1.3682231364196178], [...
# 1  [[0.7983111743858166], [1.1793349808256834], [...
# 2  [[0.5661559730096853], [1.4218048965707628], [...
# 3  [[0.5444332763276964], [1.4264965261609934], [...
# 4  [[0.6643679153685318], [1.411079197197834], [0...
#
#                                    unimodal_model.Vg  \
# 0  [[1.6338385609129495], [-1.0876522476750163], ...
# 1  [[2.086432832511592], [-0.9693949648359506], [...
# 2  [[2.062320476481625], [-0.771140280126269], [-...
# 3  [[1.9962000593780242], [-0.8115562940417956], ...
# 4  [[2.193393373309896], [-0.8362430290674218], [...
#
#   unimodal_model.kern_f.lengthscale unimodal_model.kern_f.signal_variance  \
# 0              [0.7967410769074681]                   [4.505500857572921]
# 1              [0.7782788605635261]                   [4.568827913250894]
# 2               [0.792412554737361]                   [4.460242816761743]
# 3              [0.7508625458366016]                   [4.379879972156693]
# 4              [0.6455179538237289]                   [4.309268760429087]
#
#   unimodal_model.kern_g.lengthscale unimodal_model.kern_g.signal_variance
# 0              [1.1382991613410323]                  [1.8449564231569222]
# 1              [1.0785452771411999]                   [1.664184844785945]
# 2              [1.1066106756537908]                  [1.5864833424160616]
# 3              [1.1197430885588784]                  [1.5427960034053527]
# 4              [1.0290029162784748]                  [1.7841105913657709]

# %%
plt.figure(figsize=(12,8))
plt.plot(sample_df['unimodal_model.kern_f.lengthscale'])
plt.plot(sample_df['unimodal_model.kern_f.signal_variance'])

# %%
plt.figure(figsize=(12,8))
plt.plot(sample_df['unimodal_model.kern_f.lengthscale'],
            sample_df['unimodal_model.kern_f.signal_variance'], 'k.', alpha = 0.15)
plt.xlabel('signal_lengthscale')
plt.ylabel('signal_variance')
# Out:
# Text(0,0.5,u'signal_variance')

# %%
samples.shape
# Out:
# (5000, 204)

# %%
Aq.X.shape
# Out:
# (40, 2)

# %%
model.X_concat.value.shape
# Out:
# (120, 1)

# %%
a = model.X.value
b = model.X_prime
# Out:
# array([[ 0.71428571],
#        [-0.71428571],
#        [-0.71428571],
#        [-0.14285714],
#        [ 0.42857143],
#        [-0.57142857],
#        [ 0.14285714],
#        [-0.28571429],
#        [-0.57142857],
#        [-0.57142857],
#        [ 0.57142857],
#        [-0.14285714],
#        [ 0.        ],
#        [ 0.28571429],
#        [-0.85714286],
#        [-0.28571429],
#        [ 0.28571429],
#        [-0.28571429],
#        [-0.57142857],
#        [ 0.        ],
#        [-0.14285714],
#        [-0.57142857],
#        [-0.42857143],
#        [-0.57142857],
#        [-0.85714286],
#        [ 0.85714286],
#        [-0.85714286],
#        [ 0.28571429],
#        [ 0.85714286],
#        [-0.71428571],
#        [-1.        ],
#        [-0.28571429],
#        [-0.42857143],
#        [ 0.28571429],
#        [ 0.85714286],
#        [-0.57142857],
#        [ 0.        ],
#        [-0.14285714],
#        [-1.        ],
#        [-0.14285714],
#        [ 0.57142857],
#        [ 0.71428571],
#        [-0.71428571],
#        [-0.71428571],
#        [-0.14285714],
#        [ 0.42857143],
#        [-0.57142857],
#        [ 0.14285714],
#        [-0.28571429],
#        [-0.57142857],
#        [-0.57142857],
#        [ 0.57142857],
#        [-0.14285714],
#        [ 0.        ],
#        [ 0.28571429],
#        [-0.85714286],
#        [-0.28571429],
#        [ 0.28571429],
#        [-0.28571429],
#        [-0.57142857],
#        [ 0.        ],
#        [-0.14285714],
#        [-0.57142857],
#        [-0.42857143],
#        [-0.57142857],
#        [-0.85714286],
#        [ 0.85714286],
#        [-0.85714286],
#        [ 0.28571429],
#        [ 0.85714286],
#        [-0.71428571],
#        [-1.        ],
#        [-0.28571429],
#        [-0.42857143],
#        [ 0.28571429],
#        [ 0.85714286],
#        [-0.57142857],
#        [ 0.        ],
#        [-0.14285714],
#        [-1.        ]])
