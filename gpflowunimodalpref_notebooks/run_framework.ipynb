# %% [markdown]
# # Thermal Preference Elicitation Framework
#
# Currently, this framework has been validated for only 1D (operating temp) feature./

# %% [markdown]
# # Step 1
#
# Load required modules

# %%
import sys
sys.path.append('../')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy
sns.set_context("talk", font_scale = 1.4)
from GPFlowUnimodalPref.GPUnimodalElicit import elicit
from GPFlowUnimodalPref.SynOccupant import datagen
# Out:
# /Users/nimishawalgaonkar/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# # Step 2
#
# 1. Occupant walks inside the room and is exposed to state r.
# 2. Randomly change the state of the room to new state s.
# 3. Ask the occupant which state they prefer.
# 4. If they say state current state s, then record y as 1. If they say previous state r, then record y as 0.
# This first duel is our initial duel.
# 5. Put the duel value and response in the '../data/duels/duels.csv' file

# %%
# Load the duels file
data_file = '../GPFlowUnimodalPref/data/duels/duels3.csv' # <--- you need to keep on updating this file

# %%
data = pd.read_csv(data_file)
#data = data.dropna()
data # check if the duels data is as you want it to be
# Out:
#    Tprev  Tcurrent  y   MEUI
# 0   21.0      24.0  1  0.406
# 1   24.0      27.0  1    NaN
# 2   27.0      26.5  1    NaN
# 3   26.0      26.5  0    NaN
# 4   26.5      26.0  1    NaN

# %%
iter_num = data.shape[0]

# %%
Tprev = np.array(data.Tprev) # previous state (operating temp.)
Tcurrent = np.array(data.Tcurrent) # current state <---- elicitation framework will give you this values
X = np.vstack([[Tprev, Tcurrent]]).T
X = X.astype(float) # features need to be float
X_prime = np.linspace(20, 30, 40)[:,None]
Y = np.array(data.y)[:,None] # response of the occupant <---- you need to ask occupant about this

# %% [markdown]
# # Step 3
#
# Now, we want to find the next elicited state. So, we need to use **elicit** module.

# %%
config_file = '../GPFlowUnimodalPref/config_files/thermal_config.json' # configuration for grid (how fine you want to be)
trial_num = 10 # this is just to save all the plots in '../data/results/T1' if trial_num = 1 ; T2 if trial_num = 2
model_num = 1
mcmc = True
reachable = True
savefig = True

# %%
Aq =  elicit.IntegratedAquisition(X, Y, X_prime, config_file, model_num, mcmc, reachable)
# Out:
# ----------------------------------------
# Model is 1
# burn-in sampling started
# Iteration:  100 	 Acc Rate:  54.0 %
# Iteration:  200 	 Acc Rate:  65.0 %
# Iteration:  300 	 Acc Rate:  85.0 %
# Iteration:  400 	 Acc Rate:  74.0 %
# Iteration:  500 	 Acc Rate:  76.0 %
# Iteration:  600 	 Acc Rate:  82.0 %
# Iteration:  700 	 Acc Rate:  82.0 %
# Iteration:  800 	 Acc Rate:  92.0 %
# Iteration:  900 	 Acc Rate:  78.0 %
# Iteration:  1000 	 Acc Rate:  93.0 %
# Iteration:  1100 	 Acc Rate:  80.0 %
# Iteration:  1200 	 Acc Rate:  80.0 %
# Iteration:  1300 	 Acc Rate:  83.0 %
# Iteration:  1400 	 Acc Rate:  73.0 %
# Iteration:  1500 	 Acc Rate:  89.0 %
# Iteration:  1600 	 Acc Rate:  87.0 %
# Iteration:  1700 	 Acc Rate:  69.0 %
# Iteration:  1800 	 Acc Rate:  85.0 %
# Iteration:  1900 	 Acc Rate:  73.0 %
# Iteration:  2000 	 Acc Rate:  67.0 %
# Iteration:  2100 	 Acc Rate:  91.0 %
# Iteration:  2200 	 Acc Rate:  79.0 %
# Iteration:  2300 	 Acc Rate:  92.0 %
# Iteration:  2400 	 Acc Rate:  85.0 %
# Iteration:  2500 	 Acc Rate:  86.0 %
# Iteration:  2600 	 Acc Rate:  42.0 %
# Iteration:  2700 	 Acc Rate:  57.0 %
# Iteration:  2800 	 Acc Rate:  81.0 %
# Iteration:  2900 	 Acc Rate:  86.0 %
# Iteration:  3000 	 Acc Rate:  83.0 %
# burn-in sampling ended
# Iteration:  100 	 Acc Rate:  85.0 %
# Iteration:  200 	 Acc Rate:  77.0 %
# Iteration:  300 	 Acc Rate:  86.0 %
# Iteration:  400 	 Acc Rate:  91.0 %
# Iteration:  500 	 Acc Rate:  91.0 %
# Iteration:  600 	 Acc Rate:  92.0 %
# Iteration:  700 	 Acc Rate:  80.0 %
# Iteration:  800 	 Acc Rate:  83.0 %
# Iteration:  900 	 Acc Rate:  91.0 %
# Iteration:  1000 	 Acc Rate:  79.0 %
# Iteration:  1100 	 Acc Rate:  86.0 %
# Iteration:  1200 	 Acc Rate:  71.0 %
# Iteration:  1300 	 Acc Rate:  90.0 %
# Iteration:  1400 	 Acc Rate:  63.0 %
# Iteration:  1500 	 Acc Rate:  86.0 %
# Iteration:  1600 	 Acc Rate:  82.0 %
# Iteration:  1700 	 Acc Rate:  72.0 %
# Iteration:  1800 	 Acc Rate:  57.0 %
# Iteration:  1900 	 Acc Rate:  47.0 %
# Iteration:  2000 	 Acc Rate:  80.0 %
# Iteration:  2100 	 Acc Rate:  85.0 %
# Iteration:  2200 	 Acc Rate:  50.0 %
# Iteration:  2300 	 Acc Rate:  77.0 %
# Iteration:  2400 	 Acc Rate:  76.0 %
# Iteration:  2500 	 Acc Rate:  80.0 %
# Iteration:  2600 	 Acc Rate:  67.0 %
# Iteration:  2700 	 Acc Rate:  95.0 %
# Iteration:  2800 	 Acc Rate:  71.0 %
# Iteration:  2900 	 Acc Rate:  90.0 %
# Iteration:  3000 	 Acc Rate:  81.0 %
# Iteration:  3100 	 Acc Rate:  92.0 %
# Iteration:  3200 	 Acc Rate:  79.0 %
# Iteration:  3300 	 Acc Rate:  80.0 %
# Iteration:  3400 	 Acc Rate:  89.0 %
# Iteration:  3500 	 Acc Rate:  88.0 %
# Iteration:  3600 	 Acc Rate:  83.0 %
# Iteration:  3700 	 Acc Rate:  86.0 %
# Iteration:  3800 	 Acc Rate:  95.0 %
# Iteration:  3900 	 Acc Rate:  66.0 %
# Iteration:  4000 	 Acc Rate:  96.0 %
# Iteration:  4100 	 Acc Rate:  83.0 %
# Iteration:  4200 	 Acc Rate:  78.0 %
# Iteration:  4300 	 Acc Rate:  93.0 %
# Iteration:  4400 	 Acc Rate:  85.0 %
# Iteration:  4500 	 Acc Rate:  97.0 %
# Iteration:  4600 	 Acc Rate:  86.0 %
# Iteration:  4700 	 Acc Rate:  98.0 %
# Iteration:  4800 	 Acc Rate:  93.0 %
# Iteration:  4900 	 Acc Rate:  80.0 %
# Iteration:  5000 	 Acc Rate:  80.0 %
# Iteration:  5100 	 Acc Rate:  86.0 %
# Iteration:  5200 	 Acc Rate:  81.0 %
# Iteration:  5300 	 Acc Rate:  60.0 %
# Iteration:  5400 	 Acc Rate:  84.0 %
# Iteration:  5500 	 Acc Rate:  93.0 %
# Iteration:  5600 	 Acc Rate:  80.0 %
# Iteration:  5700 	 Acc Rate:  82.0 %
# Iteration:  5800 	 Acc Rate:  88.0 %
# Iteration:  5900 	 Acc Rate:  76.0 %
# Iteration:  6000 	 Acc Rate:  61.0 %
# Iteration:  6100 	 Acc Rate:  81.0 %
# Iteration:  6200 	 Acc Rate:  81.0 %
# Iteration:  6300 	 Acc Rate:  86.0 %
# Iteration:  6400 	 Acc Rate:  93.0 %
# Iteration:  6500 	 Acc Rate:  73.0 %
# Iteration:  6600 	 Acc Rate:  92.0 %
# Iteration:  6700 	 Acc Rate:  82.0 %
# Iteration:  6800 	 Acc Rate:  85.0 %
# Iteration:  6900 	 Acc Rate:  77.0 %
# Iteration:  7000 	 Acc Rate:  99.0 %
# Iteration:  7100 	 Acc Rate:  84.0 %
# Iteration:  7200 	 Acc Rate:  95.0 %
# Iteration:  7300 	 Acc Rate:  87.0 %
# Iteration:  7400 	 Acc Rate:  88.0 %
# Iteration:  7500 	 Acc Rate:  86.0 %
# Iteration:  7600 	 Acc Rate:  84.0 %
# Iteration:  7700 	 Acc Rate:  67.0 %
# Iteration:  7800 	 Acc Rate:  73.0 %
# Iteration:  7900 	 Acc Rate:  93.0 %
# Iteration:  8000 	 Acc Rate:  86.0 %
# Iteration:  8100 	 Acc Rate:  73.0 %
# Iteration:  8200 	 Acc Rate:  82.0 %
# Iteration:  8300 	 Acc Rate:  90.0 %
# Iteration:  8400 	 Acc Rate:  93.0 %
# Iteration:  8500 	 Acc Rate:  91.0 %
# Iteration:  8600 	 Acc Rate:  84.0 %
# Iteration:  8700 	 Acc Rate:  86.0 %
# Iteration:  8800 	 Acc Rate:  87.0 %
# Iteration:  8900 	 Acc Rate:  88.0 %
# Iteration:  9000 	 Acc Rate:  76.0 %
# Iteration:  9100 	 Acc Rate:  80.0 %
# Iteration:  9200 	 Acc Rate:  53.0 %
# Iteration:  9300 	 Acc Rate:  87.0 %
# Iteration:  9400 	 Acc Rate:  64.0 %
# Iteration:  9500 	 Acc Rate:  82.0 %
# Iteration:  9600 	 Acc Rate:  82.0 %
# Iteration:  9700 	 Acc Rate:  80.0 %
# Iteration:  9800 	 Acc Rate:  89.0 %
# Iteration:  9900 	 Acc Rate:  76.0 %
# Iteration:  10000 	 Acc Rate:  91.0 %

# %%
next_state, next_duel, meanexp, max_exp_imp = Aq.EUI(iter_num, trial_num, savefig)

# %% [markdown]
# ## Step 3 is the most important step. It outputs next state.

# %% [markdown]
# # next_state ?

# %%
next_state
# Out:
# array([26.])

# %% [markdown]
# # next duel ?
#
# One of the state is always shared between two duels. So, this is nothing but concatenation of next_state with previous.

# %%
next_duel
# Out:
# array([26., 26.])

# %% [markdown]
# # max EUI ?

# %%
max_exp_imp
# Out:
# 1.485672820606283e-11

# %% [markdown]
# # Step 4 (Sanity checks)
#
# Is our framework on the right track?
#
# Check -
# 1. Max Expected Improvement value (is it less than the previous iteration's expected improvement? If so, GOOD!
# 2. Check the Expected Improvement plots. This will be saved automatically in '../data/results/T1/exp_imp_plots/iteration_num'.
# 3. Also check utility samples, how they look? Do they make sense? Is our framework going towards max? Some utility samples will also be saved in '../data/results/T1/utility_samples/iteration_num'.

# %% [markdown]
# # Step 5
#
# 1. Once you have verified that the framework is on the right track, change the operating temp of the room to the next_state as above.
# 2. Its fine if you are not able to acheive the next state accurately, just record the measured next state value.
# 2. Ask the occupant again, which state does he prefer.
# 3. Add the new measured state and response to the csv  '../data/duels/duels.csv' file.
# 4. Add max_exp_imp to the MEUI column.
# 5. Run the notebook again with updated csv file.
# 6. As you progress with the elicitation, you will notice that the ratio $(MEUI_{(i+1)} - MEUI_{(i)})/MEUI_{(i)}$ will decrease. Based on pilot study, stop the elicitation, once the ratio becomes small enough.

# %%
V = datagen.ThermalPrefDataGen(config_file)
Ynew = V.response_gen1D(next_duel[:,None].T)
Ynew
# Out:
# array([0])

# %%
Aq.m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>unimodal_model.Vf</td><td>[[ 0.62943021]</br> [ 2.81805606]</br> [-0.96615363]</br> [ 1.24167645]</br> [ 1.99197067]</br> [-1.66907369]</br> [-0.98329208]</br> [-0.0138234 ]</br> [ 2.32709394]</br> [ 1.14536246]</br> [ 2.12327676]</br> [ 0.02762805]</br> [-0.02363808]</br> [-0.75085821]</br> [ 1.37796747]</br> [ 0.23239592]</br> [-2.249244  ]</br> [-2.42758255]</br> [-0.2610038 ]</br> [-1.26428156]</br> [-0.90701241]</br> [ 0.62702244]</br> [-0.25774673]</br> [ 0.01391922]</br> [ 0.40052867]</br> [-0.92174347]</br> [ 0.78572812]</br> [-0.15524382]</br> [-1.12140672]</br> [-0.17339178]</br> [-0.79252175]</br> [ 0.74993846]</br> [-1.13367031]</br> [-2.00458237]</br> [ 1.14895169]</br> [ 1.08236438]</br> [-0.70896224]</br> [ 0.27276906]</br> [ 0.18607583]</br> [-0.19800466]</br> [-1.82677581]</br> [-1.73422065]</br> [-0.43480355]</br> [-0.12149853]</br> [ 0.82490824]</br> [ 0.99331849]</br> [ 0.83894879]</br> [ 0.24500582]</br> [ 0.21964821]</br> [ 2.06760682]]</td><td>N([0.],[1.])</td><td>(none)</td></tr><tr><td>unimodal_model.Vg</td><td>[[ 2.55931816]</br> [-1.48401936]</br> [ 0.31052988]</br> [ 0.44179425]</br> [-0.12495744]</br> [ 1.02213338]</br> [ 1.9980822 ]</br> [-0.52882742]</br> [ 0.11019018]</br> [ 0.07893784]</br> [-1.30024691]</br> [ 1.01931388]</br> [-0.72122637]</br> [-0.72098046]</br> [ 1.19734801]</br> [ 0.04420557]</br> [-1.94824497]</br> [ 0.34799486]</br> [ 0.3309712 ]</br> [-0.11338517]</br> [ 0.43434954]</br> [-1.54321949]</br> [-0.31182739]</br> [ 1.14662717]</br> [ 0.66547735]</br> [ 1.19334523]</br> [ 0.2869979 ]</br> [ 0.63667286]</br> [ 1.42885617]</br> [-0.35666065]</br> [-0.87745496]</br> [ 0.91588904]</br> [ 2.76829183]</br> [-0.42367097]</br> [-0.25858701]</br> [-0.65836159]</br> [ 0.20664469]</br> [-0.37797165]</br> [ 0.67603141]</br> [-0.19045514]</br> [-0.4704289 ]</br> [-0.48224837]</br> [ 0.32204952]</br> [ 0.28586625]</br> [ 0.02999124]</br> [-0.33371786]</br> [-2.10799543]</br> [-0.24069738]</br> [ 0.57726275]</br> [-0.9118256 ]</br> [-0.23573401]</br> [-1.9256357 ]</br> [ 0.82367174]</br> [-1.16603372]</br> [-0.13642698]</br> [-0.34720529]</br> [ 0.01434553]</br> [ 0.23639273]</br> [ 0.09416133]</br> [ 1.01347647]</br> [ 0.20388401]</br> [-1.94528314]</br> [-0.64863772]</br> [-0.29411845]</br> [-0.41681907]</br> [ 1.40505724]</br> [-0.30167737]</br> [-1.4310478 ]</br> [ 0.69512721]</br> [-0.69167836]</br> [-0.0566327 ]</br> [-1.30625779]</br> [ 0.27345481]</br> [-0.19305702]</br> [-0.45361489]</br> [ 0.14915398]</br> [-0.84777416]</br> [ 2.08489808]</br> [ 0.5751765 ]</br> [-1.30220322]]</td><td>N([0.],[1.])</td><td>(none)</td></tr><tr><td>unimodal_model.kern_f.lengthscale</td><td>[0.64912473]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>unimodal_model.kern_f.signal_variance</td><td>[0.19401499]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>unimodal_model.kern_g.lengthscale</td><td>[2.47520299]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>unimodal_model.kern_g.signal_variance</td><td>[4.56078339]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr></table>

# %%
model = Aq.m
samples = Aq.samples

# %%
sample_df = model.get_samples_df(samples)

# %%
xnew = np.linspace(20,27,20)[:,None]
xx = V.normalize1D(xnew)
meanmat = np.zeros(shape = (samples.shape[0], xx.shape[0]))
varmat = np.zeros(shape = (samples.shape[0], xx.shape[0]))
for i, s in sample_df.iterrows():
    model.set_parameter_dict(s)
    mean, v = model.predict_f(xx)
    var = v[:,:,0]
    meanmat[i,:] = mean[:,0]
    varmat[i,:] = np.diag(var)

# %%
def visualize_utility(Xgrid, Mgrid, Vargrid):
    """
    Visualize 1D utility funciton values
    Xgrid : grid states
    Mgrid : mean of GP at those finite grid points
    Vargrid : variance of GP at those finite grid points
    """
    Stdgrid = np.sqrt(Vargrid)
    lower = Mgrid - 2*Stdgrid
    upper = Mgrid + 2*Stdgrid
    #plt.figure(figsize=(12,8))
    #plt.plot(Xgrid[:,0], lower, 'g')
    #plt.plot(Xgrid[:,0], upper, 'r')
    #plt.plot(Xgrid[:,0], Mgrid, 'b')
    
    line, = plt.plot(Xgrid, Mgrid, lw = 2, color = 'b', label = 'utility', alpha = 0.5)
    plt.fill_between(Xgrid[:,0], lower, upper,
                     color = line.get_color(), alpha = 0.25)
    plt.xlabel('Temperature degC')
    plt.ylabel('Utility')
    plt.title('Utility at different temp values')
    return

# %%
mini = 1000
maxi = 1600
plt.figure(figsize=(12,8))
for i in xrange(mini,maxi):
    visualize_utility(xnew, meanmat[i,:], varmat[i,:])
#plt.legend(loc = 'best')

# %%
model
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>unimodal_model.Vf</td><td>[[ 0.74218848]</br> [ 1.90800805]</br> [ 2.40313744]</br> [-1.00803171]</br> [ 0.12422896]</br> [-0.99040274]</br> [ 0.0373115 ]</br> [ 0.1719705 ]</br> [-0.07489813]</br> [ 1.31544023]</br> [-0.73793212]</br> [-1.58158941]</br> [ 2.02406236]</br> [-0.13251704]</br> [ 1.556064  ]</br> [-0.60339731]</br> [ 0.17512125]</br> [-0.21512391]</br> [-1.09280455]</br> [-0.91847495]</br> [ 0.06809163]</br> [-0.79987874]</br> [-0.36590366]</br> [-0.09136028]</br> [-1.4818638 ]</br> [ 0.25653672]</br> [ 1.60956146]</br> [ 1.12685957]</br> [-0.15578676]</br> [-0.76887023]</br> [-1.46033112]</br> [-0.78846103]</br> [ 1.39484357]</br> [-0.42443317]</br> [ 0.63779742]</br> [ 0.34716613]</br> [-0.07342376]</br> [ 0.41787554]</br> [ 0.3749057 ]</br> [ 1.29425436]</br> [-0.85419279]</br> [ 0.81750779]</br> [ 0.44227232]</br> [ 0.27031055]</br> [ 0.39102023]</br> [-1.01200443]</br> [ 0.80373859]</br> [ 1.55329381]</br> [-0.79373124]</br> [ 0.54813837]]</td><td>N([0.],[1.])</td><td>(none)</td></tr><tr><td>unimodal_model.Vg</td><td>[[ 2.67419540e+00]</br> [-6.90447827e-01]</br> [ 5.04397188e-01]</br> [-7.70449180e-01]</br> [-3.69548539e-01]</br> [ 9.83976734e-01]</br> [ 1.47886984e+00]</br> [ 5.33537554e-01]</br> [-4.48801809e-01]</br> [-7.49582415e-01]</br> [ 2.55375569e-02]</br> [-7.47116301e-01]</br> [-1.11679957e+00]</br> [-5.90032697e-02]</br> [-1.15625845e-01]</br> [-2.74262388e-02]</br> [ 1.84144262e+00]</br> [-2.04830817e+00]</br> [-1.54286785e-01]</br> [-1.80691893e+00]</br> [ 1.50756787e+00]</br> [ 1.27766520e-01]</br> [ 1.46995224e-01]</br> [ 1.20625458e+00]</br> [-9.23059466e-01]</br> [ 1.98496746e-01]</br> [-1.74242499e-03]</br> [-2.51539527e-01]</br> [-3.03410616e-01]</br> [ 5.93822276e-01]</br> [ 1.47635407e+00]</br> [ 1.89701228e-01]</br> [ 1.84919955e+00]</br> [ 9.05200302e-03]</br> [ 1.22848930e+00]</br> [ 8.67432702e-01]</br> [ 6.15653514e-01]</br> [ 4.38649527e-01]</br> [ 2.08211599e+00]</br> [-5.08188020e-02]</br> [-3.96091520e-01]</br> [ 1.38499524e+00]</br> [-6.99244478e-01]</br> [ 3.71238660e-01]</br> [-4.67348693e-01]</br> [ 1.03972470e-01]</br> [-3.98707819e-01]</br> [ 1.29023165e+00]</br> [ 1.71491882e+00]</br> [-3.45395806e-01]</br> [ 5.77338237e-01]</br> [-9.45007535e-01]</br> [ 6.15386193e-01]</br> [-3.45344267e-01]</br> [ 8.10309197e-01]</br> [-2.06914693e-02]</br> [ 4.95250656e-01]</br> [-6.71411529e-02]</br> [ 1.20978063e+00]</br> [ 8.97953904e-01]</br> [-4.37475179e-01]</br> [ 3.39789708e-01]</br> [-6.47365134e-01]</br> [ 6.80823746e-01]</br> [-1.18295017e-01]</br> [-1.38257803e+00]</br> [-1.01070208e+00]</br> [-1.84678343e-01]</br> [-1.88233463e-01]</br> [-2.14398573e-01]</br> [-5.74507646e-01]</br> [ 1.52973885e+00]</br> [ 2.31281932e+00]</br> [-1.38806149e-01]</br> [-2.09988415e-01]</br> [-1.27561890e+00]</br> [-1.38942057e+00]</br> [-7.45550169e-01]</br> [-1.09617010e+00]</br> [ 3.33879217e-03]]</td><td>N([0.],[1.])</td><td>(none)</td></tr><tr><td>unimodal_model.kern_f.lengthscale</td><td>[4.18740431]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>unimodal_model.kern_f.signal_variance</td><td>[0.76055791]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>unimodal_model.kern_g.lengthscale</td><td>[3.93734058]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>unimodal_model.kern_g.signal_variance</td><td>[1.51237797]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr></table>

# %%
from scipy.stats import norm
def diff_norm_g(m, samples, Xgridnorm, Xgrid, mini, maxi):
    """
    Different utilities along with the associated uncertainities
    """
    plt.figure(figsize=(12,8))
    for i in xrange(mini,maxi):
        m.set_state(samples[i,:])
        g = m.predict_g_samples(Xgridnorm, 1)
        plt.plot(Xgrid, norm.cdf(g[0,:,:]), 'b', lw=2, alpha = 0.25)
    a = np.linspace(19.8, 27.2, 100)
    plt.plot(a, 0.5*np.ones(a.shape[0]), 'k')
    plt.xlim(19.8,27.2)
    plt.xlabel('Temperature degC')
    plt.ylabel('Indicator')
    plt.title('Indicator at different temp values')

# %%
diff_norm_g(model, samples, xx, xnew, 0, 5000)

# %%
from scipy.stats import norm
def diff_g(m, samples, Xgridnorm, Xgrid, mini, maxi):
    """
    Different utilities along with the associated uncertainities
    """
    plt.figure(figsize=(12,8))
    for i in xrange(mini,maxi):
        m.set_state(samples[i,:])
        g = m.predict_g_samples(Xgridnorm, 1)
        plt.plot(Xgrid, g[0,:,:], 'b', lw=2, alpha = 0.25)
    a = np.linspace(19.8, 27.2, 100)
    plt.plot(a, np.zeros(a.shape[0]), 'k')
    plt.xlabel('Temperature degC')
    plt.ylabel('Latent g')
    plt.title('Latent g at different temp values')
    plt.xlim(19.8,27.2)

# %%
diff_g(model, samples, xx, xnew, 0, 2600)

# %%
model.set_state(samples[2])
model
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>unimodal_model.Vf</td><td>[[ 1.29740477]</br> [ 1.62106734]</br> [ 0.62204402]</br> [ 0.12932623]</br> [-1.05535009]</br> [-0.20161822]</br> [ 0.85391489]</br> [ 1.39414006]</br> [-1.74944792]</br> [-0.10219732]</br> [ 0.16849563]</br> [ 0.28385947]</br> [ 1.89480456]</br> [-1.51656765]</br> [-1.41762119]</br> [-0.54232277]</br> [ 0.44288235]</br> [-0.36649903]</br> [-0.57507322]</br> [-0.27564461]</br> [ 2.2884004 ]</br> [ 0.81914334]</br> [ 0.88581282]</br> [ 0.22537058]</br> [ 0.46868835]</br> [-0.05790832]</br> [-0.28603907]</br> [-1.29420023]</br> [ 1.12710524]</br> [ 0.4517227 ]</br> [ 1.86405173]</br> [ 1.25898966]</br> [-0.22201432]</br> [ 0.17626744]</br> [ 2.02874348]</br> [-0.49145166]</br> [ 2.01095289]</br> [-0.02081018]</br> [-0.92392511]</br> [-0.08591713]</br> [ 0.596489  ]</br> [-1.73374501]</br> [ 0.90540563]</br> [-1.21063244]</br> [ 0.04466145]</br> [-1.25351766]</br> [ 0.85837955]</br> [ 0.27052158]</br> [ 0.8262864 ]</br> [ 0.59936678]]</td><td>N([0.],[1.])</td><td>(none)</td></tr><tr><td>unimodal_model.Vg</td><td>[[ 1.68789165e+00]</br> [-8.80900444e-01]</br> [ 4.06555939e-01]</br> [-5.03176828e-01]</br> [-9.44705908e-01]</br> [ 6.96385422e-02]</br> [-7.53151740e-01]</br> [-6.81405669e-01]</br> [ 7.08722919e-01]</br> [ 1.11511419e-02]</br> [-2.74938617e-01]</br> [-3.14523694e-01]</br> [-7.62551919e-02]</br> [-1.32748410e-01]</br> [ 8.69965748e-01]</br> [-8.43123103e-01]</br> [-2.29568426e+00]</br> [-1.25720815e-01]</br> [-4.73686882e-01]</br> [ 6.67315013e-02]</br> [-6.15912327e-01]</br> [-6.95461402e-01]</br> [-7.58343720e-01]</br> [-8.58817574e-01]</br> [-3.21926772e-01]</br> [ 4.22834615e-02]</br> [ 7.32595724e-01]</br> [ 1.94676353e+00]</br> [ 6.63115424e-01]</br> [ 8.43574320e-01]</br> [-1.16434240e+00]</br> [ 2.49432616e-01]</br> [-1.10522055e-01]</br> [ 7.88512655e-01]</br> [-5.85274137e-02]</br> [-7.35195211e-01]</br> [-4.22737688e-01]</br> [-8.86412299e-01]</br> [ 6.99940860e-01]</br> [ 6.50052489e-01]</br> [-7.08136723e-01]</br> [ 4.43969456e-01]</br> [-3.09826873e-01]</br> [-8.73768124e-01]</br> [-7.89706423e-01]</br> [-4.94537316e-01]</br> [ 3.61228479e-01]</br> [ 4.45680882e-01]</br> [-2.28676452e+00]</br> [ 1.12048013e+00]</br> [-2.69450004e-01]</br> [ 6.27778699e-01]</br> [ 9.52994475e-01]</br> [-2.04805154e+00]</br> [-9.10991874e-01]</br> [ 1.60519196e+00]</br> [-2.23116545e-01]</br> [-8.71538665e-01]</br> [ 5.68077748e-01]</br> [ 1.30248750e+00]</br> [ 2.35743778e-01]</br> [-1.56096762e-01]</br> [ 5.21210083e-01]</br> [ 6.29921476e-01]</br> [-7.07790498e-01]</br> [-7.31552219e-02]</br> [ 4.60461398e-01]</br> [-3.56542185e-02]</br> [ 6.41428997e-01]</br> [-5.65976699e-01]</br> [-7.66084562e-01]</br> [-7.44614073e-01]</br> [ 1.06036888e-01]</br> [ 8.06274113e-01]</br> [-1.75184012e-01]</br> [-7.91322579e-04]</br> [ 5.51871613e-01]</br> [ 6.35718097e-01]</br> [-4.61423825e-01]</br> [-8.16433401e-03]]</td><td>N([0.],[1.])</td><td>(none)</td></tr><tr><td>unimodal_model.kern_f.lengthscale</td><td>[1.49487081]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>unimodal_model.kern_f.signal_variance</td><td>[0.42080767]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>unimodal_model.kern_g.lengthscale</td><td>[3.00534751]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>unimodal_model.kern_g.signal_variance</td><td>[4.54148539]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr></table>

# %%
sample_df = model.get_samples_df(samples)
sample_df.head()
# Out:
#                                    unimodal_model.Vf  \
# 0  [[1.2299576622907635], [1.6173675351593202], [...
# 1  [[1.2048217983989247], [1.6335624725911468], [...
# 2  [[1.2974047733404825], [1.6210673431778786], [...
# 3  [[0.5726169519268431], [1.4222706312511488], [...
# 4  [[0.4975720822536086], [1.2426476151199886], [...
#
#                                    unimodal_model.Vg  \
# 0  [[1.8187520093303844], [-1.236538144061037], [...
# 1  [[1.876998513771828], [-1.1313206899747617], [...
# 2  [[1.6878916453429873], [-0.8809004442324423], ...
# 3  [[1.7265640736603485], [-0.9595399113771862], ...
# 4  [[1.797307962663222], [-1.2061001905090016], [...
#
#   unimodal_model.kern_f.lengthscale unimodal_model.kern_f.signal_variance  \
# 0              [1.3604828425850326]                    [0.50291703260842]
# 1              [1.3586053099624553]                  [0.4072679240011843]
# 2              [1.4948708078816955]                 [0.42080767461202223]
# 3              [1.5698700899682694]                  [0.5849710343230303]
# 4              [1.7161465678815013]                  [0.6036758761642403]
#
#   unimodal_model.kern_g.lengthscale unimodal_model.kern_g.signal_variance
# 0               [2.887495878304176]                   [4.477516377428257]
# 1              [2.9568307916553414]                   [4.689981593935241]
# 2              [3.0053475068595077]                   [4.541485389005636]
# 3               [3.088251875933348]                   [4.957736625747328]
# 4               [3.173404967067193]                    [4.75213111336414]

# %%
plt.figure(figsize=(12,8))
plt.plot(sample_df['unimodal_model.kern_f.lengthscale'])
plt.plot(sample_df['unimodal_model.kern_f.signal_variance'])

# %%
plt.figure(figsize=(12,8))
plt.plot(sample_df['unimodal_model.kern_f.lengthscale'],
            sample_df['unimodal_model.kern_f.signal_variance'], 'k.', alpha = 0.15)
plt.xlabel('signal_lengthscale')
plt.ylabel('signal_variance')
# Out:
# Text(0,0.5,u'signal_variance')

# %%
samples.shape
# Out:
# (5000, 134)
