# %%
import numpy as np
import gpflow
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy
sns.set_context("talk", font_scale = 1.4)
# Out:
# /Users/nimishawalgaonkar/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
a = 2
b = 2
X = np.linspace(0,1,5)[:,None]
X_prime = np.linspace(0,1,20)[:,None]
Y = scipy.stats.beta.pdf(X, a, b)

# %%
Xplot = np.linspace(0,1,100)[:,None]
Yplot = scipy.stats.beta.pdf(Xplot, a, b)
plt.figure(figsize = (12,8))
plt.plot(Xplot, Yplot)

# %%
plt.figure(figsize = (12,8))
plt.scatter(X, Y)

# %%
import sys
sys.path.append('../')
from GPFlowUnimodal.ker_w_der import ExtendRBF1D
from GPFlowUnimodal.unimodal_gpmc import UnimodalGPMC

# %%
m = UnimodalGPMC(X, Y, X_prime)
m.likelihood.noise_variance = 0.01
m.likelihood.noise_variance.fixed = True

# %%
m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>unimodal_model.Vf</td><td>[[0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]]</td><td>N([0.],[1.])</td><td>(none)</td></tr><tr><td>unimodal_model.Vg</td><td>[[0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]]</td><td>N([0.],[1.])</td><td>(none)</td></tr><tr><td>unimodal_model.kern_f.lengthscale</td><td>[1.]</td><td>None</td><td>+ve</td></tr><tr><td>unimodal_model.kern_f.signal_variance</td><td>[1.]</td><td>None</td><td>+ve</td></tr><tr><td>unimodal_model.kern_g.lengthscale</td><td>[1.]</td><td>None</td><td>+ve</td></tr><tr><td>unimodal_model.kern_g.signal_variance</td><td>[1.]</td><td>None</td><td>+ve</td></tr><tr><td>unimodal_model.likelihood.noise_variance</td><td>[0.01]</td><td>None</td><td>[FIXED]</td></tr></table>

# %%
m.kern_f.lengthscale.prior = gpflow.priors.Gamma(1., 1.)
m.kern_f.signal_variance.prior = gpflow.priors.Gamma(1.,1.)
m.kern_g.lengthscale.prior = gpflow.priors.Gamma(1., 1.)
m.kern_g.signal_variance.prior = gpflow.priors.Gamma(1.,1.)

# %%
m.optimize(maxiter=150) # start near MAP
# Out:
#       fun: array([68.0580841])
#  hess_inv: <69x69 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-3.89911163e+00,  1.19658492e+00, -1.40951656e+00, -2.10508422e-01,
#         9.87008547e-01,  8.38831793e-04, -2.81970109e-04, -3.09665942e-04,
#        -3.91590823e-04, -3.43707481e-04, -2.11422163e-04, -8.04593382e-05,
#         3.90392263e-05,  1.42339858e-04,  1.99671771e-04,  1.96779749e-04,
#         1.54477929e-04,  1.01610625e-04,  5.75399219e-05,  2.83644756e-05,
#         1.10071330e-05,  1.54367836e-06, -1.98313865e-06, -2.10517550e-06,
#        -1.21375861e-06,  4.68524223e-01, -4.02557138e-01,  1.16787114e-01,
#         2.50577841e-01,  3.02059451e-01,  1.46084122e-01,  1.51188203e-01,
#         1.54883791e-01,  1.03793872e-01,  6.57670955e-02,  5.20595877e-02,
#         3.92840745e-02,  2.34536111e-02,  1.16892032e-02,  5.96226952e-03,
#         3.25164977e-03,  1.51151682e-03,  4.25416301e-04, -3.97051552e-05,
#        -1.27324214e-04,  6.75293681e-06,  1.72085309e-06,  1.57967085e-06,
#         2.19644130e-06,  2.52934043e-06,  2.10938371e-06,  1.28435238e-06,
#         4.04464410e-07, -4.33098367e-07, -1.10204711e-06, -1.37308498e-06,
#        -1.12462995e-06, -4.11142306e-07,  7.32166618e-07,  2.33843349e-06,
#         4.08720421e-06,  4.75600825e-06,  3.66898795e-06,  2.02003123e-06,
#         8.22245031e-07, -2.07684726e+00,  2.04833071e-01,  1.22975003e+00,
#        -5.74983551e-01])
#   message: 'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 195
#       nit: 35
#    status: 2
#   success: False
#         x: array([-1.99398947e-02,  1.52820971e+00,  5.68477076e-02, -1.99943781e-01,
#        -6.95726075e-01,  8.38831793e-04, -2.81970109e-04, -3.09665942e-04,
#        -3.91590823e-04, -3.43707481e-04, -2.11422163e-04, -8.04593382e-05,
#         3.90392263e-05,  1.42339858e-04,  1.99671771e-04,  1.96779749e-04,
#         1.54477929e-04,  1.01610625e-04,  5.75399219e-05,  2.83644756e-05,
#         1.10071330e-05,  1.54367836e-06, -1.98313865e-06, -2.10517550e-06,
#        -1.21375861e-06,  1.60425713e+00, -6.86757777e-01, -9.41788751e-01,
#        -5.16059221e-01, -4.82816745e-01, -3.89575720e-01, -3.06956154e-01,
#        -2.54412027e-01, -2.01236599e-01, -1.45204199e-01, -1.00978287e-01,
#        -7.02612809e-02, -4.95268176e-02, -3.36178474e-02, -2.13400354e-02,
#        -1.27060698e-02, -7.13655161e-03, -3.72234965e-03, -1.72101401e-03,
#        -6.34288106e-04,  6.75293681e-06,  1.72085309e-06,  1.57967085e-06,
#         2.19644130e-06,  2.52934043e-06,  2.10938371e-06,  1.28435238e-06,
#         4.04464410e-07, -4.33098367e-07, -1.10204711e-06, -1.37308498e-06,
#        -1.12462995e-06, -4.11142306e-07,  7.32166618e-07,  2.33843349e-06,
#         4.08720421e-06,  4.75600825e-06,  3.66898795e-06,  2.02003123e-06,
#         8.22245031e-07, -7.16977663e-01,  1.43809376e+00, -4.27435557e-01,
#         1.25153757e+00])

# %%
samples = m.sample(1000, Lmax = 20, epsilon = 0.01, thin = 5, burn = 1000, verbose= True)
# Out:
# burn-in sampling started
# Iteration:  100 	 Acc Rate:  83.0 %
# Iteration:  200 	 Acc Rate:  86.0 %
# Iteration:  300 	 Acc Rate:  94.0 %
# Iteration:  400 	 Acc Rate:  85.0 %
# Iteration:  500 	 Acc Rate:  72.0 %
# Iteration:  600 	 Acc Rate:  71.0 %
# Iteration:  700 	 Acc Rate:  72.0 %
# Iteration:  800 	 Acc Rate:  87.0 %
# Iteration:  900 	 Acc Rate:  70.0 %
# Iteration:  1000 	 Acc Rate:  66.0 %
# burn-in sampling ended
# Iteration:  100 	 Acc Rate:  86.0 %
# Iteration:  200 	 Acc Rate:  86.0 %
# Iteration:  300 	 Acc Rate:  89.0 %
# Iteration:  400 	 Acc Rate:  84.0 %
# Iteration:  500 	 Acc Rate:  89.0 %
# Iteration:  600 	 Acc Rate:  91.0 %
# Iteration:  700 	 Acc Rate:  79.0 %
# Iteration:  800 	 Acc Rate:  95.0 %
# Iteration:  900 	 Acc Rate:  69.0 %
# Iteration:  1000 	 Acc Rate:  69.0 %
# Iteration:  1100 	 Acc Rate:  72.0 %
# Iteration:  1200 	 Acc Rate:  83.0 %
# Iteration:  1300 	 Acc Rate:  94.0 %
# Iteration:  1400 	 Acc Rate:  93.0 %
# Iteration:  1500 	 Acc Rate:  90.0 %
# Iteration:  1600 	 Acc Rate:  74.0 %
# Iteration:  1700 	 Acc Rate:  78.0 %
# Iteration:  1800 	 Acc Rate:  86.0 %
# Iteration:  1900 	 Acc Rate:  63.0 %
# Iteration:  2000 	 Acc Rate:  72.0 %
# Iteration:  2100 	 Acc Rate:  66.0 %
# Iteration:  2200 	 Acc Rate:  77.0 %
# Iteration:  2300 	 Acc Rate:  85.0 %
# Iteration:  2400 	 Acc Rate:  96.0 %
# Iteration:  2500 	 Acc Rate:  69.0 %
# Iteration:  2600 	 Acc Rate:  86.0 %
# Iteration:  2700 	 Acc Rate:  85.0 %
# Iteration:  2800 	 Acc Rate:  70.0 %
# Iteration:  2900 	 Acc Rate:  86.0 %
# Iteration:  3000 	 Acc Rate:  89.0 %
# Iteration:  3100 	 Acc Rate:  72.0 %
# Iteration:  3200 	 Acc Rate:  73.0 %
# Iteration:  3300 	 Acc Rate:  80.0 %
# Iteration:  3400 	 Acc Rate:  86.0 %
# Iteration:  3500 	 Acc Rate:  86.0 %
# Iteration:  3600 	 Acc Rate:  91.0 %
# Iteration:  3700 	 Acc Rate:  85.0 %
# Iteration:  3800 	 Acc Rate:  75.0 %
# Iteration:  3900 	 Acc Rate:  71.0 %
# Iteration:  4000 	 Acc Rate:  69.0 %
# Iteration:  4100 	 Acc Rate:  77.0 %
# Iteration:  4200 	 Acc Rate:  95.0 %
# Iteration:  4300 	 Acc Rate:  92.0 %
# Iteration:  4400 	 Acc Rate:  93.0 %
# Iteration:  4500 	 Acc Rate:  63.0 %
# Iteration:  4600 	 Acc Rate:  77.0 %
# Iteration:  4700 	 Acc Rate:  89.0 %
# Iteration:  4800 	 Acc Rate:  74.0 %
# Iteration:  4900 	 Acc Rate:  74.0 %
# Iteration:  5000 	 Acc Rate:  73.0 %

# %%
#plt.figure(figsize=(16, 4))
#plt.plot(samples)

# %%
sample_df = m.get_samples_df(samples)
sample_df.head()
# Out:
#                                    unimodal_model.Vf  \
# 0  [[0.031775877559259376], [1.3106240318212188],...
# 1  [[-0.01846617639039264], [1.359792222267096], ...
# 2  [[0.12291099484085573], [1.296798730347406], [...
# 3  [[0.283564668543881], [1.3104248191856933], [1...
# 4  [[0.018088018811109177], [1.3106367544510868],...
#
#                                    unimodal_model.Vg  \
# 0  [[1.5032093965202649], [-1.5797143402830065], ...
# 1  [[1.1818628055831326], [-1.3421108794792813], ...
# 2  [[0.9789361733334255], [-1.4904037872469225], ...
# 3  [[1.0032136683689186], [-1.7334172777955719], ...
# 4  [[1.0970883677596648], [-1.7413022569913683], ...
#
#   unimodal_model.kern_f.lengthscale unimodal_model.kern_f.signal_variance  \
# 0              [0.2069492819538877]                  [0.8229606566019241]
# 1             [0.21534633331568848]                  [0.8647461317806094]
# 2             [0.21065106551877477]                  [0.8713297608668634]
# 3             [0.20887339254529855]                  [0.7121347977090333]
# 4             [0.22765416179561226]                  [0.6541750342244853]
#
#   unimodal_model.kern_g.lengthscale unimodal_model.kern_g.signal_variance  \
# 0              [0.5483416599881709]                   [1.221319901357034]
# 1              [0.6007077375776817]                   [1.052377322864963]
# 2              [0.7372745363443397]                   [1.057925707958874]
# 3              [0.6513650973650378]                  [1.1024637477107941]
# 4              [0.6623013137884456]                   [1.147935034088563]
#
#   unimodal_model.likelihood.noise_variance
# 0                                   [0.01]
# 1                                   [0.01]
# 2                                   [0.01]
# 3                                   [0.01]
# 4                                   [0.01]

# %%
sample_df = m.get_samples_df(samples)
#plot the function posterior
xx = np.linspace(-0.1, 1.1, 100)[:,None]
plt.figure(figsize=(12, 6))
for i, s in sample_df.iterrows():
    m.set_parameter_dict(s)
    f = m.predict_f_samples(xx, 200)
    plt.plot(xx, f[0,:,:], 'b', lw=2, alpha = 0.05)
    
plt.plot(X, Y, 'kx', mew=2)
_ = plt.xlim(xx.min(), xx.max())
_ = plt.ylim(-2, 2)

# %%
sample_df = m.get_samples_df(samples)
#plot the function posterior
xx = np.linspace(-0.1, 1.1, 100)[:,None]
plt.figure(figsize=(12, 6))
for i, s in sample_df.iterrows():
    m.set_parameter_dict(s)
    g = m.predict_g_samples(xx, 200)
    plt.plot(xx, g[0,:,:], 'b', lw=2, alpha = 0.05)

# %%
from scipy.stats import norm
sample_df = m.get_samples_df(samples)
#plot the function posterior
xx = np.linspace(-0.1, 1.1, 100)[:,None]
plt.figure(figsize=(12, 6))
for i, s in sample_df.iterrows():
    m.set_parameter_dict(s)
    g = m.predict_g_samples(xx, 200)
    plt.plot(xx, g[0,:,:], 'b', lw=2, alpha = 0.05)
