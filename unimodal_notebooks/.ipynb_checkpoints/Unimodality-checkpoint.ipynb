# %%
import numpy as np
import gpflow
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy
sns.set_context("talk", font_scale = 1.4)
# Out:
# /Users/nimishawalgaonkar/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
a = 2
b = 2
X = np.linspace(0,1,4)[:,None]
X_prime = np.linspace(0,1,4)[:,None]
Y = scipy.stats.beta.pdf(X, a, b)

# %%
Xplot = np.linspace(0,1,100)[:,None]
Yplot = scipy.stats.beta.pdf(Xplot, a, b)
plt.figure(figsize = (12,8))
plt.plot(Xplot, Yplot)

# %%
plt.figure(figsize = (12,8))
plt.scatter(X, Y)

# %%
import sys
sys.path.append('../')
from GPFlowUnimodal.ker_w_der import ExtendRBF1D
from GPFlowUnimodal.unimodal_gpmc import UnimodalGPMC

# %%
m = UnimodalGPMC(X, Y, X_prime)
m.likelihood.noise_variance = 0.01
m.likelihood.noise_variance.fixed = True

# %%
m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>unimodal_model.Vf</td><td>[[0.]</br> [0.]</br> [0.]</br> [0.]]</td><td>N([0.],[1.])</td><td>(none)</td></tr><tr><td>unimodal_model.Vg</td><td>[[0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]]</td><td>N([0.],[1.])</td><td>(none)</td></tr><tr><td>unimodal_model.kern_f.lengthscale</td><td>[1.]</td><td>None</td><td>+ve</td></tr><tr><td>unimodal_model.kern_f.signal_variance</td><td>[1.]</td><td>None</td><td>+ve</td></tr><tr><td>unimodal_model.kern_g.lengthscale</td><td>[1.]</td><td>None</td><td>+ve</td></tr><tr><td>unimodal_model.kern_g.signal_variance</td><td>[1.]</td><td>None</td><td>+ve</td></tr><tr><td>unimodal_model.likelihood.noise_variance</td><td>[0.01]</td><td>None</td><td>[FIXED]</td></tr></table>

# %%
m.kern_f.lengthscale.prior = gpflow.priors.Gamma(1., 1.)
m.kern_f.signal_variance.prior = gpflow.priors.Gamma(1.,1.)
m.kern_g.lengthscale.prior = gpflow.priors.Gamma(1., 1.)
m.kern_g.signal_variance.prior = gpflow.priors.Gamma(1.,1.)

# %%
m.optimize(maxiter=150) # start near MAP
# Out:
#       fun: array([18.73201195])
#  hess_inv: <16x16 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.40264473e-03,  4.75556588e-02,  2.42908185e-02, -7.48864887e-07,
#        -3.85455162e-03, -2.80396045e-02,  1.51440722e-03, -1.37173448e-03,
#        -7.15571029e-04,  9.47418268e-07, -1.02219319e-06,  1.01429152e-06,
#        -1.15445596e-02, -1.15454183e-02,  5.56059483e-03, -2.17478296e-03])
#   message: 'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 180
#       nit: 26
#    status: 0
#   success: True
#         x: array([ 1.56998125e-05, -7.01229162e-06,  2.79913169e-06, -7.48869510e-07,
#         6.62518410e-01, -2.59594034e-01, -6.56274927e-01, -2.13751379e-01,
#        -7.15571029e-04,  9.47418268e-07, -1.02219319e-06,  1.01429152e-06,
#        -2.30916551e-02, -2.30916860e-02, -5.90725206e-01,  6.20532772e-01])

# %%
samples = m.sample(2000, Lmax = 40, epsilon = 0.005, thin = 3, burn = 200, verbose= True)
# Out:
# burn-in sampling started
# Iteration:  100 	 Acc Rate:  54.0 %
# Iteration:  200 	 Acc Rate:  90.0 %
# burn-in sampling ended
# Iteration:  100 	 Acc Rate:  75.0 %
# Iteration:  200 	 Acc Rate:  96.0 %
# Iteration:  300 	 Acc Rate:  85.0 %
# Iteration:  400 	 Acc Rate:  92.0 %
# Iteration:  500 	 Acc Rate:  92.0 %
# Iteration:  600 	 Acc Rate:  86.0 %
# Iteration:  700 	 Acc Rate:  96.0 %
# Iteration:  800 	 Acc Rate:  91.0 %
# Iteration:  900 	 Acc Rate:  84.0 %
# Iteration:  1000 	 Acc Rate:  92.0 %
# Iteration:  1100 	 Acc Rate:  85.0 %
# Iteration:  1200 	 Acc Rate:  80.0 %
# Iteration:  1300 	 Acc Rate:  93.0 %
# Iteration:  1400 	 Acc Rate:  95.0 %
# Iteration:  1500 	 Acc Rate:  97.0 %
# Iteration:  1600 	 Acc Rate:  90.0 %
# Iteration:  1700 	 Acc Rate:  68.0 %
# Iteration:  1800 	 Acc Rate:  79.0 %
# Iteration:  1900 	 Acc Rate:  92.0 %
# Iteration:  2000 	 Acc Rate:  92.0 %
# Iteration:  2100 	 Acc Rate:  75.0 %
# Iteration:  2200 	 Acc Rate:  72.0 %
# Iteration:  2300 	 Acc Rate:  85.0 %
# Iteration:  2400 	 Acc Rate:  79.0 %
# Iteration:  2500 	 Acc Rate:  65.0 %
# Iteration:  2600 	 Acc Rate:  85.0 %
# Iteration:  2700 	 Acc Rate:  90.0 %
# Iteration:  2800 	 Acc Rate:  87.0 %
# Iteration:  2900 	 Acc Rate:  88.0 %
# Iteration:  3000 	 Acc Rate:  98.0 %
# Iteration:  3100 	 Acc Rate:  91.0 %
# Iteration:  3200 	 Acc Rate:  88.0 %
# Iteration:  3300 	 Acc Rate:  86.0 %
# Iteration:  3400 	 Acc Rate:  77.0 %
# Iteration:  3500 	 Acc Rate:  93.0 %
# Iteration:  3600 	 Acc Rate:  95.0 %
# Iteration:  3700 	 Acc Rate:  90.0 %
# Iteration:  3800 	 Acc Rate:  88.0 %
# Iteration:  3900 	 Acc Rate:  85.0 %
# Iteration:  4000 	 Acc Rate:  89.0 %
# Iteration:  4100 	 Acc Rate:  82.0 %
# Iteration:  4200 	 Acc Rate:  84.0 %
# Iteration:  4300 	 Acc Rate:  92.0 %
# Iteration:  4400 	 Acc Rate:  89.0 %
# Iteration:  4500 	 Acc Rate:  91.0 %
# Iteration:  4600 	 Acc Rate:  88.0 %
# Iteration:  4700 	 Acc Rate:  85.0 %
# Iteration:  4800 	 Acc Rate:  78.0 %
# Iteration:  4900 	 Acc Rate:  83.0 %
# Iteration:  5000 	 Acc Rate:  96.0 %
# Iteration:  5100 	 Acc Rate:  77.0 %
# Iteration:  5200 	 Acc Rate:  85.0 %
# Iteration:  5300 	 Acc Rate:  96.0 %
# Iteration:  5400 	 Acc Rate:  87.0 %
# Iteration:  5500 	 Acc Rate:  83.0 %
# Iteration:  5600 	 Acc Rate:  89.0 %
# Iteration:  5700 	 Acc Rate:  99.0 %
# Iteration:  5800 	 Acc Rate:  96.0 %
# Iteration:  5900 	 Acc Rate:  98.0 %
# Iteration:  6000 	 Acc Rate:  97.0 %

# %%
#plt.figure(figsize=(16, 4))
#plt.plot(samples)

# %%
sample_df = m.get_samples_df(samples)
sample_df.head()
# Out:
#                                    unimodal_model.Vf  \
# 0  [[1.624925956456741], [0.7730291198886304], [0...
# 1  [[1.8011147772671023], [0.8410910960860705], [...
# 2  [[1.928644246907069], [0.9513827689024915], [1...
# 3  [[1.437907962514403], [0.5882652404725773], [0...
# 4  [[1.4491864221008046], [0.5757227626317566], [...
#
#                                    unimodal_model.Vg  \
# 0  [[1.5486045184013997], [-0.3976383758212827], ...
# 1  [[1.5768894668055031], [-0.4295972237671443], ...
# 2  [[1.28110844849955], [-0.3921731123377125], [0...
# 3  [[1.879690070674786], [-0.3449493285174302], [...
# 4  [[1.9967823575279304], [-0.4203721182494302], ...
#
#   unimodal_model.kern_f.lengthscale unimodal_model.kern_f.signal_variance  \
# 0              [0.2746701172655256]                  [0.2368147528498128]
# 1              [0.3148801197142274]                 [0.26723663138328346]
# 2              [0.3287725195349623]                  [0.2577932438727543]
# 3               [0.503287417789875]                 [0.15066680068419866]
# 4             [0.48882515927516207]                 [0.14567845942110413]
#
#   unimodal_model.kern_g.lengthscale unimodal_model.kern_g.signal_variance  \
# 0              [1.9660161037297044]                  [1.2190969092199313]
# 1              [1.8855869729196195]                  [1.1183354002401529]
# 2              [1.8395949403633742]                  [1.1616861466414625]
# 3              [1.2873178611999796]                  [1.0667077915291248]
# 4              [1.3081034522278414]                  [1.1281905919744462]
#
#   unimodal_model.likelihood.noise_variance
# 0                                   [0.01]
# 1                                   [0.01]
# 2                                   [0.01]
# 3                                   [0.01]
# 4                                   [0.01]

# %%
sample_df = m.get_samples_df(samples)
#plot the function posterior
xx = np.linspace(-0.1, 1.1, 100)[:,None]
plt.figure(figsize=(12, 6))
for i, s in sample_df.iterrows():
    m.set_parameter_dict(s)
    f = m.predict_f_samples(xx, 20)
    plt.plot(xx, f[0,:,:], 'b', lw=2, alpha = 0.05)
    
plt.plot(X, Y, 'kx', mew=2)
_ = plt.xlim(xx.min(), xx.max())
_ = plt.ylim(-2, 2)

# %%
xx = np.linspace(-0.1, 1.1, 100)[:,None]
plt.figure(figsize=(12, 6))
for i, s in sample_df.iterrows():
    m.set_parameter_dict(s)
    g = m.predict_g_samples(xx, 200)
    plt.plot(xx, g[0,:,:], 'b', lw=2, alpha = 0.05)

# %%
from scipy.stats import norm
#plot the function posterior
xx = np.linspace(-0.1, 1.1, 100)[:,None]
plt.figure(figsize=(12, 6))
for i, s in sample_df.iterrows():
    m.set_parameter_dict(s)
    g = m.predict_g_samples(xx, 1)
    plt.plot(xx, norm.cdf(g[0,:,:]), 'b', lw=2, alpha = 0.05)

# %%
meanmat = np.zeros(shape = (samples.shape[0], xx.shape[0]))
varmat = np.zeros(shape = (samples.shape[0], xx.shape[0]))
for i, s in sample_df.iterrows():
    m.set_parameter_dict(s)
    mean, v = m.predict_f(xx)
    var = v[:,:,0]
    meanmat[i,:] = mean[:,0]
    varmat[i,:] = np.diag(var)

# %%
def visualize_utility(Xgrid, Mgrid, Vargrid):
    """
    Visualize 1D utility funciton values
    Xgrid : grid states
    Mgrid : mean of GP at those finite grid points
    Vargrid : variance of GP at those finite grid points
    """
    Stdgrid = np.sqrt(Vargrid)
    lower = Mgrid - 2*Stdgrid
    upper = Mgrid + 2*Stdgrid
    #plt.figure(figsize=(12,8))
    #plt.plot(Xgrid[:,0], lower, 'g')
    #plt.plot(Xgrid[:,0], upper, 'r')
    #plt.plot(Xgrid[:,0], Mgrid, 'b')
    
    line, = plt.plot(Xgrid, Mgrid, lw = 2)
    plt.fill_between(Xgrid[:,0], lower, upper,
                     color = line.get_color(), alpha = 0.25)
    plt.xlabel('Temperature degC')
    plt.ylabel('Utility')
    plt.title('Utility at different temp values')
    return

# %%
plt.figure(figsize=(12,8))
for i in xrange(2):
    visualize_utility(xx, meanmat[i,:], varmat[i,:])

# %%
g[0,:,:].shape
# Out:
# (100, 1)

# %%
g.shape
# Out:
# (1, 100, 1)

# %%
m.set_state(samples[i,:])
# Out:
# 21

# %%
samples.shape
# Out:
# (2000, 21)

# %%
samples[0]
# Out:
# array([-0.09647947,  1.96513754,  0.12949842,  0.24197405, -0.906949  ,
#         0.51524815, -0.47311488, -1.13762174,  1.26217026,  0.81370757,
#        -0.81613259, -0.5092585 , -1.75326673,  0.16291561,  0.08055294,
#        -0.63825934, -0.72234525, -0.87641838,  0.49389754, -0.96159029,
#         0.98110414])

# %%
samples[3]
# Out:
# array([ 0.02271066,  1.56754984,  0.04967067, -0.23512064, -0.74736451,
#         0.49863881, -0.4939343 , -1.16314132,  0.93781158,  0.51266466,
#        -0.52776957, -0.37725395, -1.97697817,  1.14574166,  0.31603303,
#        -0.64484224, -0.23903247, -0.700794  ,  1.06948319, -0.71674462,
#         1.16382756])
