# %% [markdown]
# GP Regression with GPflow
# --
#
# *James Hensman, 2015, 2016*
#
# GP regression (with Gaussian noise) is the most straightforward GP model in GPflow. Because of the conjugacy of the latent process and the noise, the marginal likelihood $p(\mathbf y\,|\,\theta)$ can be computed exactly.
#
# This notebook shows how to build a GPR model, estimate the parameters $\theta$ by both maximum likelihood and MCMC.

# %%
import gpflow
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline
# Out:
# /Users/nimishawalgaonkar/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
import sys
sys.path.append('../')
from GPPref import mean_func

# %% [markdown]
# First build a simple data set.

# %%
N = 12
X = np.random.rand(N,1)
Y = np.sin(12*X) + 0.66*np.cos(25*X) + np.random.randn(N,1)*0.1 + 3
plt.plot(X, Y, 'kx', mew=2)

# %% [markdown]
# ### Model construction
#
# A GPflow model is created by instantiating one of the GPflow model classes, in this case GPR. we'll make a kernel `k` and instantiate a GPR object using the generated data and the kernel. We'll set the variance of the likelihood to a sensible initial guess, too.

# %%
k = gpflow.kernels.Matern52(1, lengthscales=0.3)
m = gpflow.gpr.GPR(X, Y, kern=k)
m.likelihood.variance = 0.01

# %%
m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>name.kern.lengthscales</td><td>[0.3]</td><td>None</td><td>+ve</td></tr><tr><td>name.kern.variance</td><td>[1.]</td><td>None</td><td>+ve</td></tr><tr><td>name.likelihood.variance</td><td>[0.01]</td><td>None</td><td>+ve</td></tr></table>

# %% [markdown]
# ### Prediction
#
# GPflow models have several prediction methods:

# %% [markdown]
#  - `m.predict_f` returns the mean and variance of the latent function (f) at the points Xnew.
#
#  - `m.predict_f_full_cov` additionally returns the full covariance matrix of the prediction.
#
#  - `m.predict_y` returns the mean and variance of a new data point (i.e. includes the noise varaince). In the case of non-Gaussian likelihoods, the variance is computed by (numerically) integrating the non-Gaussian likelihood.
#
#  - `m.predict_f_samples` returns samples of the latent function
#
#  - `m.predict_density` returns the log-density of the points Ynew at Xnew.
#
# We'll use `predict_y` to make a simple plotting function.

# %%
def plot(m):
    xx = np.linspace(-0.1, 1.1, 100)[:,None]
    mean, var = m.predict_y(xx)
    plt.figure(figsize=(12, 6))
    plt.plot(X, Y, 'kx', mew=2)
    plt.plot(xx, mean, 'b', lw=2)
    plt.fill_between(xx[:,0], mean[:,0] - 2*np.sqrt(var[:,0]), mean[:,0] + 2*np.sqrt(var[:,0]), color='blue', alpha=0.2)
    plt.xlim(-0.1, 1.1)
plot(m)

# %% [markdown]
# ### Using mean functions
#
# All GPflow models can have parameterized mean functions, some simple ones are provided in `gpflow.mean_functions`. Here's a model with a Linear mean function.

# %%
reload(mean_func)
# Out:
# <module 'GPPref.mean_func' from '../GPPref/mean_func.pyc'>

# %%
k = gpflow.kernels.Matern52(1, lengthscales=0.3)
#meanf = gpflow.mean_functions.Linear(1,0)
meanf = mean_func.Parabola(1,0)
m = gpflow.gpr.GPR(X, Y, k, meanf)
m.likelihood.variance = 0.01

# %%
aa = gpflow.priors.Gaussian(0., 10.)

# %%
aa.sample()
# Out:
# array([-2.21044481])

# %% [markdown]
# ### Maximum Likelihood estimation of $\theta$
#
# Getting the ML estimate of the parameters is a simple call to `optimize()`. By default, GPflow plugs into the L-BFGS-B algorithm via scipy. Here are the parameters before optimization:

# %%
m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>name.kern.lengthscales</td><td>[0.3]</td><td>None</td><td>+ve</td></tr><tr><td>name.kern.variance</td><td>[1.]</td><td>None</td><td>+ve</td></tr><tr><td>name.likelihood.variance</td><td>[0.01]</td><td>None</td><td>+ve</td></tr><tr><td>name.mean_function.A</td><td>[1.]</td><td>None</td><td>(none)</td></tr><tr><td>name.mean_function.mu</td><td>[0.]</td><td>None</td><td>(none)</td></tr></table>

# %% [markdown]
# Here are the parameters after optimization, and a new plot.

# %%
m.optimize()
plot(m)
m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>name.kern.lengthscales</td><td>[41236.24589294]</td><td>None</td><td>+ve</td></tr><tr><td>name.kern.variance</td><td>[14.60361873]</td><td>None</td><td>+ve</td></tr><tr><td>name.likelihood.variance</td><td>[0.05423698]</td><td>None</td><td>+ve</td></tr><tr><td>name.mean_function.A</td><td>[3.87409497]</td><td>None</td><td>(none)</td></tr><tr><td>name.mean_function.mu</td><td>[0.31306004]</td><td>None</td><td>(none)</td></tr></table>

# %% [markdown]
# ### MCMC for $\theta$
#
# Here's a quick demonstratino of how to obtain posteriors over the hyper-parameters in GPregression. First, we'll set come priors on the kernel parameters, then we'll run MCMC and see how much posterior uncertainty there is in the parameters.
#
# First we'll choose rather arbitrary priors.

# %%
m.mean_function
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>mean_function.A</td><td>[3.87409497]</td><td>None</td><td>(none)</td></tr><tr><td>mean_function.mu</td><td>[0.31306004]</td><td>None</td><td>(none)</td></tr></table>

# %%
m.kern.lengthscales.prior = gpflow.priors.Gamma(1., 1.)
m.kern.variance.prior = gpflow.priors.Gamma(1., 1.)
m.likelihood.variance.prior = gpflow.priors.Gamma(1., 1.)
m.mean_function.A.prior = gpflow.priors.Gaussian(0., 10.)
m.mean_function.mu.prior = gpflow.priors.Gaussian(0., 1.)
m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>name.kern.lengthscales</td><td>[41236.24589294]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>name.kern.variance</td><td>[14.60361873]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>name.likelihood.variance</td><td>[0.05423698]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>name.mean_function.A</td><td>[3.87409497]</td><td>U(0.0,10.0)</td><td>(none)</td></tr><tr><td>name.mean_function.mu</td><td>[0.31306004]</td><td>N([0.],[1.])</td><td>(none)</td></tr></table>

# %%
m.sample?

# %%
samples = m.sample(1000, Lmax = 20, epsilon= 0.1, thin = 5, burn = 1000, verbose= 1)
# Out:
# burn-in sampling started
# Iteration:  100 	 Acc Rate:  72.0 %
# Iteration:  200 	 Acc Rate:  87.0 %
# Iteration:  300 	 Acc Rate:  99.0 %
# Iteration:  400 	 Acc Rate:  92.0 %
# Iteration:  500 	 Acc Rate:  86.0 %
# Iteration:  600 	 Acc Rate:  83.0 %
# Iteration:  700 	 Acc Rate:  64.0 %
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# Iteration:  800 	 Acc Rate:  37.0 %
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# Iteration:  900 	 Acc Rate:  59.0 %
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# Iteration:  1000 	 Acc Rate:  48.0 %
# burn-in sampling ended
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# Iteration:  100 	 Acc Rate:  34.0 %
# Iteration:  200 	 Acc Rate:  82.0 %
# warning: numerical instability.                  Rejecting this proposal prematurely
# Iteration:  300 	 Acc Rate:  71.0 %
# Iteration:  400 	 Acc Rate:  88.0 %
# Iteration:  500 	 Acc Rate:  95.0 %
# Iteration:  600 	 Acc Rate:  76.0 %
# Iteration:  700 	 Acc Rate:  92.0 %
# warning: numerical instability.                  Rejecting this proposal prematurely
# Iteration:  800 	 Acc Rate:  65.0 %
# Iteration:  900 	 Acc Rate:  56.0 %
# Iteration:  1000 	 Acc Rate:  79.0 %
# warning: numerical instability.                  Rejecting this proposal prematurely
# Iteration:  1100 	 Acc Rate:  82.0 %
# Iteration:  1200 	 Acc Rate:  86.0 %
# warning: numerical instability.                  Rejecting this proposal prematurely
# Iteration:  1300 	 Acc Rate:  49.0 %
# Iteration:  1400 	 Acc Rate:  76.0 %
# Iteration:  1500 	 Acc Rate:  74.0 %
# Iteration:  1600 	 Acc Rate:  96.0 %
# Iteration:  1700 	 Acc Rate:  77.0 %
# Iteration:  1800 	 Acc Rate:  78.0 %
# Iteration:  1900 	 Acc Rate:  86.0 %
# Iteration:  2000 	 Acc Rate:  75.0 %
# Iteration:  2100 	 Acc Rate:  93.0 %
# Iteration:  2200 	 Acc Rate:  79.0 %
# Iteration:  2300 	 Acc Rate:  70.0 %
# Iteration:  2400 	 Acc Rate:  72.0 %
# Iteration:  2500 	 Acc Rate:  61.0 %
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# Iteration:  2600 	 Acc Rate:  71.0 %
# Iteration:  2700 	 Acc Rate:  88.0 %
# Iteration:  2800 	 Acc Rate:  87.0 %
# Iteration:  2900 	 Acc Rate:  78.0 %
# Iteration:  3000 	 Acc Rate:  68.0 %
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# Iteration:  3100 	 Acc Rate:  57.0 %
# Iteration:  3200 	 Acc Rate:  81.0 %
# warning: numerical instability.                  Rejecting this proposal prematurely
# Iteration:  3300 	 Acc Rate:  74.0 %
# warning: numerical instability.                  Rejecting this proposal prematurely
# Iteration:  3400 	 Acc Rate:  90.0 %
# Iteration:  3500 	 Acc Rate:  92.0 %
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# Iteration:  3600 	 Acc Rate:  75.0 %
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# Iteration:  3700 	 Acc Rate:  21.0 %
# Iteration:  3800 	 Acc Rate:  86.0 %
# Iteration:  3900 	 Acc Rate:  57.0 %
# Iteration:  4000 	 Acc Rate:  68.0 %
# warning: numerical instability.                  Rejecting this proposal prematurely
# Iteration:  4100 	 Acc Rate:  76.0 %
# warning: numerical instability.                  Rejecting this proposal prematurely
# Iteration:  4200 	 Acc Rate:  78.0 %
# warning: numerical instability.                  Rejecting this proposal prematurely
# Iteration:  4300 	 Acc Rate:  88.0 %
# Iteration:  4400 	 Acc Rate:  89.0 %
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# Iteration:  4500 	 Acc Rate:  3.0 %
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# Iteration:  4600 	 Acc Rate:  58.0 %
# warning: numerical instability.                  Rejecting this proposal prematurely
# Iteration:  4700 	 Acc Rate:  70.0 %
# Iteration:  4800 	 Acc Rate:  93.0 %
# Iteration:  4900 	 Acc Rate:  94.0 %
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# warning: numerical instability.                  Rejecting this proposal prematurely
# Iteration:  5000 	 Acc Rate:  45.0 %

# %%
plt.figure(figsize=(16, 4))
plt.plot(samples)
# Out:
# [<matplotlib.lines.Line2D at 0x181d9ddc90>,
#  <matplotlib.lines.Line2D at 0x181d9ddc10>,
#  <matplotlib.lines.Line2D at 0x181d9dde10>,
#  <matplotlib.lines.Line2D at 0x181d9dded0>,
#  <matplotlib.lines.Line2D at 0x181d9ddfd0>]

# %% [markdown]
# The samples are in the same form as the sampler runs (i.e. in the unconstrained space, with and fixed parameters removed). Each row is one sample, and each column is one free variable. GPflow can convert the samples into a nice DataFrame, which is much more interpretable.

# %%
sample_df = m.get_samples_df(samples)
sample_df.head()
# Out:
#   name.kern.lengthscales   name.kern.variance name.likelihood.variance  \
# 0    [40693.12552716917]  [4.781058394620685]    [0.10810913806106337]
# 1    [40693.12552716917]  [4.781058394620685]    [0.10810913806106337]
# 2    [40693.12552716917]  [4.781058394620685]    [0.10810913806106337]
# 3   [40694.424719410374]  [5.410108448942334]     [0.0856655671598563]
# 4   [40694.424719410374]  [5.410108448942334]     [0.0856655671598563]
#
#   name.mean_function.A  name.mean_function.mu
# 0   [5.72652665122897]   [0.3925447882806291]
# 1   [5.72652665122897]   [0.3925447882806291]
# 2   [5.72652665122897]   [0.3925447882806291]
# 3  [5.944931449270573]  [0.35503220641650013]
# 4  [5.944931449270573]  [0.35503220641650013]

# %%
# make a more informative plot
plt.figure(figsize=(16, 4))
for lab, s in sample_df.iteritems():
    plt.plot(s, label=lab)
_ = plt.legend(loc=0)

# %%
f, axs = plt.subplots(1,3, figsize=(12,4))

axs[0].plot(sample_df['model.likelihood.variance'],
            sample_df['model.kern.variance'], 'k.', alpha = 0.15)
axs[0].set_xlabel('noise_variance')
axs[0].set_ylabel('signal_variance')

axs[1].plot(sample_df['model.likelihood.variance'],
            sample_df['model.kern.lengthscales'], 'k.', alpha = 0.15)
axs[1].set_xlabel('noise_variance')
axs[1].set_ylabel('lengthscale')

axs[2].plot(sample_df['model.kern.lengthscales'],
            sample_df['model.kern.variance'], 'k.', alpha = 0.1)
axs[2].set_xlabel('lengthscale')
axs[2].set_ylabel('signal_variance')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-1da7de1dca38> in <module>()
#       1 f, axs = plt.subplots(1,3, figsize=(12,4))
#       2
# ----> 3 axs[0].plot(sample_df['model.likelihood.variance'],
#       4             sample_df['model.kern.variance'], 'k.', alpha = 0.15)
#       5 axs[0].set_xlabel('noise_variance')
#
# /Users/nimishawalgaonkar/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /Users/nimishawalgaonkar/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /Users/nimishawalgaonkar/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /Users/nimishawalgaonkar/anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /Users/nimishawalgaonkar/anaconda2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'model.likelihood.variance'

# %% [markdown]
# To plot the posterior of predictions, we'll iterate through the samples and set the model state with each samnple. then, for tht state (set of hyper-parameters) we'll draw some samples from the prediction function.

# %%
#plot the function posterior
xx = np.linspace(-0.1, 1.1, 100)[:,None]
plt.figure(figsize=(12, 6))
for i, s in sample_df.iterrows():
    m.set_parameter_dict(s)
    f = m.predict_f_samples(xx, 1)
    plt.plot(xx, f[0,:,:], 'b', lw=2, alpha = 0.05)
    
plt.plot(X, Y, 'kx', mew=2)
_ = plt.xlim(xx.min(), xx.max())
_ = plt.ylim(0, 6)

# %%
np.min(m.mean_function.A.get_samples_df(samples))
# Out:
# array([-5.04006174])
