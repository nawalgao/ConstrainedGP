# %%
import numpy as np
import gpflow
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_context("talk", font_scale = 1.4)
X = np.linspace(0.,1, 2)[:,None]
X_prime = np.linspace(0, 1, 20)[:,None]
Y = 5*X

plt.plot(X, Y)
plt.scatter(X, Y, color = 'k')

# %%
import sys
sys.path.append('../')
from GPMonotone.ker_w_der import ExtendRBF1D
from GPMonotone.monotone_gpmc import MonotoneGPMC

# %%
K = ExtendRBF1D()

# %%
m = MonotoneGPMC(X, Y, X_prime, values)
m.likelihood.noise_variance = 0.01
m.likelihood.noise_variance.fixed = True

# %%
m.kern.lengthscale.prior = gpflow.priors.Gamma(1., 1.)
m.kern.signal_variance.prior = gpflow.priors.Gamma(1.,1.)
m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>monotonic_model.V</td><td>[[0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]]</td><td>N([0.],[1.])</td><td>(none)</td></tr><tr><td>monotonic_model.kern.lengthscale</td><td>[1.]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>monotonic_model.kern.signal_variance</td><td>[1.]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>monotonic_model.likelihood.noise_variance</td><td>[0.01]</td><td>None</td><td>[FIXED]</td></tr></table>

# %%
m.optimize(maxiter=150) # start near MAP
# Out:
#       fun: array([26.04798482])
#  hess_inv: <24x24 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 4.92099363e-06,  3.51422776e-05, -5.16833325e-07,  1.59440729e-06,
#         5.96065640e-07,  3.79499922e-07,  2.01730625e-07,  1.43353932e-07,
#         1.22790053e-07,  1.02979745e-07,  7.58706146e-08,  4.70081862e-08,
#         1.94801877e-08, -9.55872547e-09, -4.58718476e-08, -9.40544828e-08,
#        -1.47566009e-07, -1.76445968e-07, -1.53958888e-07, -1.00968537e-07,
#        -5.26192116e-08, -2.11884868e-08, -9.39697160e-06,  1.42167822e-05])
#   message: 'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 66
#       nit: 40
#    status: 0
#   success: True
#         x: array([ 7.31350140e-04,  2.64295116e+00, -5.16833325e-07,  1.59440729e-06,
#         5.96065640e-07,  3.79499922e-07,  2.01730625e-07,  1.43353932e-07,
#         1.22790053e-07,  1.02979745e-07,  7.58706146e-08,  4.70081862e-08,
#         1.94801877e-08, -9.55872547e-09, -4.58718476e-08, -9.40544828e-08,
#        -1.47566009e-07, -1.76445968e-07, -1.53958888e-07, -1.00968537e-07,
#        -5.26192116e-08, -2.11884868e-08, -5.23632085e-01,  3.56630338e+00])

# %%
m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>monotonic_model.V</td><td>[[ 7.31350140e-04]</br> [ 2.64295116e+00]</br> [-5.16833325e-07]</br> [ 1.59440729e-06]</br> [ 5.96065640e-07]</br> [ 3.79499922e-07]</br> [ 2.01730625e-07]</br> [ 1.43353932e-07]</br> [ 1.22790053e-07]</br> [ 1.02979745e-07]</br> [ 7.58706146e-08]</br> [ 4.70081862e-08]</br> [ 1.94801877e-08]</br> [-9.55872547e-09]</br> [-4.58718476e-08]</br> [-9.40544828e-08]</br> [-1.47566009e-07]</br> [-1.76445968e-07]</br> [-1.53958888e-07]</br> [-1.00968537e-07]</br> [-5.26192116e-08]</br> [-2.11884868e-08]]</td><td>N([0.],[1.])</td><td>(none)</td></tr><tr><td>monotonic_model.kern.lengthscale</td><td>[0.46522141]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>monotonic_model.kern.signal_variance</td><td>[3.59417256]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>monotonic_model.likelihood.noise_variance</td><td>[0.01]</td><td>None</td><td>[FIXED]</td></tr></table>

# %%
samples = m.sample(500, Lmax = 20, epsilon = 0.01, thin = 5, burn = 1000, verbose= True)
# Out:
# burn-in sampling started
# Iteration:  100 	 Acc Rate:  94.0 %
# Iteration:  200 	 Acc Rate:  94.0 %
# Iteration:  300 	 Acc Rate:  98.0 %
# Iteration:  400 	 Acc Rate:  91.0 %
# Iteration:  500 	 Acc Rate:  92.0 %
# Iteration:  600 	 Acc Rate:  98.0 %
# Iteration:  700 	 Acc Rate:  83.0 %
# Iteration:  800 	 Acc Rate:  95.0 %
# Iteration:  900 	 Acc Rate:  93.0 %
# Iteration:  1000 	 Acc Rate:  77.0 %
# burn-in sampling ended
# Iteration:  100 	 Acc Rate:  82.0 %
# Iteration:  200 	 Acc Rate:  77.0 %
# Iteration:  300 	 Acc Rate:  69.0 %
# Iteration:  400 	 Acc Rate:  94.0 %
# Iteration:  500 	 Acc Rate:  88.0 %
# Iteration:  600 	 Acc Rate:  90.0 %
# Iteration:  700 	 Acc Rate:  99.0 %
# Iteration:  800 	 Acc Rate:  99.0 %
# Iteration:  900 	 Acc Rate:  91.0 %
# Iteration:  1000 	 Acc Rate:  95.0 %
# Iteration:  1100 	 Acc Rate:  79.0 %
# Iteration:  1200 	 Acc Rate:  96.0 %
# Iteration:  1300 	 Acc Rate:  98.0 %
# Iteration:  1400 	 Acc Rate:  92.0 %
# Iteration:  1500 	 Acc Rate:  91.0 %
# Iteration:  1600 	 Acc Rate:  78.0 %
# Iteration:  1700 	 Acc Rate:  92.0 %
# Iteration:  1800 	 Acc Rate:  88.0 %
# Iteration:  1900 	 Acc Rate:  90.0 %
# Iteration:  2000 	 Acc Rate:  94.0 %
# Iteration:  2100 	 Acc Rate:  87.0 %
# Iteration:  2200 	 Acc Rate:  97.0 %
# Iteration:  2300 	 Acc Rate:  84.0 %
# Iteration:  2400 	 Acc Rate:  91.0 %
# Iteration:  2500 	 Acc Rate:  86.0 %

# %%
plt.figure(figsize=(16, 4))
plt.plot(samples)
# Out:
# [<matplotlib.lines.Line2D at 0x1a2242ca90>,
#  <matplotlib.lines.Line2D at 0x1a2242cb50>,
#  <matplotlib.lines.Line2D at 0x1a2242cc10>,
#  <matplotlib.lines.Line2D at 0x1a2242ccd0>,
#  <matplotlib.lines.Line2D at 0x1a2242cd90>,
#  <matplotlib.lines.Line2D at 0x1a2242ce50>,
#  <matplotlib.lines.Line2D at 0x1a2242cf10>,
#  <matplotlib.lines.Line2D at 0x1a2242cfd0>,
#  <matplotlib.lines.Line2D at 0x1a224390d0>,
#  <matplotlib.lines.Line2D at 0x1a22439190>,
#  <matplotlib.lines.Line2D at 0x1a22439250>,
#  <matplotlib.lines.Line2D at 0x1a22439310>,
#  <matplotlib.lines.Line2D at 0x1a224393d0>,
#  <matplotlib.lines.Line2D at 0x1a22439490>,
#  <matplotlib.lines.Line2D at 0x1a22439550>,
#  <matplotlib.lines.Line2D at 0x1a22439610>,
#  <matplotlib.lines.Line2D at 0x1a224396d0>,
#  <matplotlib.lines.Line2D at 0x1a22439790>,
#  <matplotlib.lines.Line2D at 0x1a22439850>,
#  <matplotlib.lines.Line2D at 0x1a22439910>,
#  <matplotlib.lines.Line2D at 0x1a223fff50>,
#  <matplotlib.lines.Line2D at 0x1a22439a90>,
#  <matplotlib.lines.Line2D at 0x1a22439b50>,
#  <matplotlib.lines.Line2D at 0x1a22439c10>]

# %%
sample_df = m.get_samples_df(samples)
sample_df.head()
# Out:
#                                    monotonic_model.V  \
# 0  [[0.05542945197364357], [2.4395568728562704], ...
# 1  [[-0.04262826782156116], [2.5992627559963792],...
# 2  [[-0.10044953122224505], [2.5818788169385765],...
# 3  [[-0.11978240109350359], [2.4409262289886664],...
# 4  [[-0.08341620286152855], [2.6454668539058326],...
#
#   monotonic_model.kern.lengthscale monotonic_model.kern.signal_variance  \
# 0            [0.31631038870829364]                  [4.082779648147054]
# 1             [0.4733957140540731]                  [3.828910481751727]
# 2            [0.40849009375625117]                  [3.698105139693158]
# 3            [0.38703056962331583]                  [4.143736502649666]
# 4            [0.39621967578463513]                  [3.784412473253873]
#
#   monotonic_model.likelihood.noise_variance
# 0                                    [0.01]
# 1                                    [0.01]
# 2                                    [0.01]
# 3                                    [0.01]
# 4                                    [0.01]

# %%
plt.plot(sample_df['monotonic_model.kern.signal_variance'])

# %%
plt.plot(sample_df['monotonic_model.kern.lengthscale'])

# %%
plt.scatter(sample_df['monotonic_model.kern.signal_variance'], sample_df['monotonic_model.kern.lengthscale'])

# %%
sample_df = m.get_samples_df(samples)
#plot the function posterior
xx = np.linspace(-0.1, 1.1, 100)[:,None]
plt.figure(figsize=(12, 6))
for i, s in sample_df.iterrows():
    m.set_parameter_dict(s)
    f = m.predict_f_samples(xx, 1)
    plt.plot(xx, f[0,:,:], 'b', lw=2, alpha = 0.05)
    
plt.plot(X, Y, 'kx', mew=2)
_ = plt.xlim(xx.min(), xx.max())
_ = plt.ylim(-6, 6)
