# %%
import numpy as np
import gpflow
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_context("talk", font_scale = 1.4)
X = np.linspace(0.,1, 3)[:,None]
X_prime = np.linspace(0, 1, 3)[:,None]
Y = 5*X

plt.plot(X, Y)
# Out:
# /Users/nimishawalgaonkar/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
import sys
sys.path.append('../')
from GPMonotone.ker_w_der import ExtendRBF1D
from GPMonotone.monotone_gpmc import MonotoneGPMC

# %%
K = ExtendRBF1D()

# %%
m = MonotoneGPMC(X, Y, X_prime)
m.likelihood.noise_variance = 0.01
m.likelihood.noise_variance.fixed = True

# %%
m.kern.lengthscale.prior = gpflow.priors.Gamma(1., 1.)
m.kern.signal_variance.prior = gpflow.priors.Gamma(1.,1.)
m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>monotonic_model.V</td><td>[[0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]]</td><td>N([0.],[1.])</td><td>(none)</td></tr><tr><td>monotonic_model.kern.lengthscale</td><td>[1.]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>monotonic_model.kern.signal_variance</td><td>[1.]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>monotonic_model.likelihood.noise_variance</td><td>[0.01]</td><td>None</td><td>[FIXED]</td></tr></table>

# %%
m.optimize(maxiter=150) # start near MAP
# Out:
#       fun: array([23.76161608])
#  hess_inv: <8x8 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.03086326,  0.16560133,  0.03005624,  0.02205293, -0.06090465,
#         0.0378898 , -0.14929012,  0.03225804])
#   message: 'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 231
#       nit: 55
#    status: 2
#   success: False
#         x: array([ 4.76879472e-04,  1.57972979e+00,  2.12717210e+00,  2.20529325e-02,
#        -6.09046515e-02,  3.78898008e-02, -5.52730722e-01,  3.54080238e+00])

# %%
m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>monotonic_model.V</td><td>[[ 4.76879472e-04]</br> [ 1.57972979e+00]</br> [ 2.12717210e+00]</br> [ 2.20529325e-02]</br> [-6.09046515e-02]</br> [ 3.78898008e-02]]</td><td>N([0.],[1.])</td><td>(none)</td></tr><tr><td>monotonic_model.kern.lengthscale</td><td>[0.45449527]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>monotonic_model.kern.signal_variance</td><td>[3.56938117]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>monotonic_model.likelihood.noise_variance</td><td>[0.01]</td><td>None</td><td>[FIXED]</td></tr></table>

# %%
samples = m.sample(2000, Lmax = 20, epsilon = 0.01, thin = 5, burn = 1000, verbose= True)
# Out:
# burn-in sampling started
# Iteration:  100 	 Acc Rate:  96.0 %
# Iteration:  200 	 Acc Rate:  100.0 %
# Iteration:  300 	 Acc Rate:  96.0 %
# Iteration:  400 	 Acc Rate:  82.0 %
# Iteration:  500 	 Acc Rate:  88.0 %
# Iteration:  600 	 Acc Rate:  78.0 %
# Iteration:  700 	 Acc Rate:  86.0 %
# Iteration:  800 	 Acc Rate:  91.0 %
# Iteration:  900 	 Acc Rate:  68.0 %
# Iteration:  1000 	 Acc Rate:  89.0 %
# burn-in sampling ended
# Iteration:  100 	 Acc Rate:  79.0 %
# Iteration:  200 	 Acc Rate:  76.0 %
# Iteration:  300 	 Acc Rate:  92.0 %
# Iteration:  6400 	 Acc Rate:  71.0 %
# Iteration:  6500 	 Acc Rate:  70.0 %
# Iteration:  6600 	 Acc Rate:  88.0 %
# Iteration:  6700 	 Acc Rate:  82.0 %
# Iteration:  6800 	 Acc Rate:  94.0 %
# Iteration:  6900 	 Acc Rate:  88.0 %
# Iteration:  7000 	 Acc Rate:  67.0 %
# Iteration:  7100 	 Acc Rate:  80.0 %
# Iteration:  7200 	 Acc Rate:  87.0 %
# Iteration:  7300 	 Acc Rate:  87.0 %
# Iteration:  7400 	 Acc Rate:  92.0 %
# Iteration:  7500 	 Acc Rate:  80.0 %
# Iteration:  7600 	 Acc Rate:  86.0 %
# Iteration:  7700 	 Acc Rate:  91.0 %
# Iteration:  7800 	 Acc Rate:  71.0 %
# Iteration:  7900 	 Acc Rate:  61.0 %
# Iteration:  8000 	 Acc Rate:  87.0 %
# Iteration:  8100 	 Acc Rate:  87.0 %
# Iteration:  8200 	 Acc Rate:  89.0 %
# Iteration:  8300 	 Acc Rate:  60.0 %
# Iteration:  8400 	 Acc Rate:  79.0 %
# Iteration:  8500 	 Acc Rate:  94.0 %
# Iteration:  8600 	 Acc Rate:  89.0 %
# Iteration:  8700 	 Acc Rate:  96.0 %
# Iteration:  8800 	 Acc Rate:  93.0 %
# Iteration:  8900 	 Acc Rate:  84.0 %
# Iteration:  9000 	 Acc Rate:  90.0 %
# Iteration:  9100 	 Acc Rate:  92.0 %
# Iteration:  9200 	 Acc Rate:  86.0 %
# Iteration:  9300 	 Acc Rate:  75.0 %
# Iteration:  9400 	 Acc Rate:  83.0 %
# Iteration:  9500 	 Acc Rate:  85.0 %
# Iteration:  9600 	 Acc Rate:  80.0 %
# Iteration:  9700 	 Acc Rate:  93.0 %
# Iteration:  9800 	 Acc Rate:  79.0 %
# Iteration:  9900 	 Acc Rate:  83.0 %
# Iteration:  10000 	 Acc Rate:  79.0 %

# %%
plt.figure(figsize=(16, 4))
plt.plot(samples)
# Out:
# [<matplotlib.lines.Line2D at 0x1a22df7810>,
#  <matplotlib.lines.Line2D at 0x1a22df78d0>,
#  <matplotlib.lines.Line2D at 0x1a22df7990>,
#  <matplotlib.lines.Line2D at 0x1a22df7a50>,
#  <matplotlib.lines.Line2D at 0x1a22df7b10>,
#  <matplotlib.lines.Line2D at 0x1a22df7bd0>,
#  <matplotlib.lines.Line2D at 0x1a22df7c90>,
#  <matplotlib.lines.Line2D at 0x1a22df7d50>]

# %%
sample_df = m.get_samples_df(samples)
sample_df.head()
# Out:
#                                    monotonic_model.V  \
# 0  [[0.030399073757608436], [1.3669377303413894],...
# 1  [[-0.04339307193831492], [1.2103960700969023],...
# 2  [[-0.03598239825087034], [1.3213289663709906],...
# 3  [[-0.04370894633245408], [1.2818671586542438],...
# 4  [[-0.035227327085344755], [1.258894142965865],...
#
#   monotonic_model.kern.lengthscale monotonic_model.kern.signal_variance  \
# 0             [0.1509750586027106]                 [3.7160586261559523]
# 1            [0.15065696130144424]                  [3.872831364289647]
# 2            [0.12036569684167914]                 [3.7641824777399444]
# 3            [0.09474087924057212]                  [3.779979710055019]
    val = var/l**2*np.exp(-1./(2*l**2)*sqr)*(1 - 1./l**2*sqr)
    return val

def rbf_n_d(x1, x2, var, l):
    """
    cov between GP at x1 points and derivative of GP at x2 points
    """
    diff = x1 - x2.T
    sqr = diff**2
    val = -var/l**2*np.exp(-1./(2*l**2)*sqr)*diff
    return val

def K_m_m(X, X_prime, var, l):
    k1 = rbf(X, X, var, l)
    k2 = rbf_n_d(X, X_prime, var, l)
    k3 = k2.T
    k4 = rbf_d(X_prime, X_prime, var, l)
    K11 = np.hstack([k1,k2])
    K22 = np.hstack([k3, k4])
    KK = np.vstack([K11, K22])
    return KK

def K_m_n(Xnew, X, X_prime, var, l):
    k1 = rbf(X, Xnew, var, l)
    k2 = rbf_n_d(Xnew, X_prime, var, l)
    kk = np.vstack([k1, k2])
    return kk

# %%
rbf(X, X, vv, ll)
# Out:
# array([[3.74994980e+00, 1.74190505e-01, 1.74590879e-05],
#        [1.74190505e-01, 3.74994980e+00, 1.74190505e-01],
#        [1.74590879e-05, 1.74190505e-01, 3.74994980e+00]])

# %%
rbf_d(X, X, vv, ll)
# Out:
# array([[ 9.20792125e+01, -2.19792858e+01, -1.00980344e-02],
#        [-2.19792858e+01,  9.20792125e+01, -2.19792858e+01],
#        [-1.00980344e-02, -2.19792858e+01,  9.20792125e+01]])

# %%
rbf_n_d(X, X, vv, ll)
# Out:
# array([[-0.00000000e+00,  2.13860523e+00,  4.28704157e-04],
#        [-2.13860523e+00, -0.00000000e+00,  2.13860523e+00],
#        [-4.28704157e-04, -2.13860523e+00, -0.00000000e+00]])

# %%
K_m_m(X, X_prime, vv, ll)
# Out:
# array([[ 3.74994980e+00,  1.74190505e-01,  1.74590879e-05,
#         -0.00000000e+00,  2.13860523e+00,  4.28704157e-04],
#        [ 1.74190505e-01,  3.74994980e+00,  1.74190505e-01,
#         -2.13860523e+00, -0.00000000e+00,  2.13860523e+00],
#        [ 1.74590879e-05,  1.74190505e-01,  3.74994980e+00,
#         -4.28704157e-04, -2.13860523e+00, -0.00000000e+00],
#        [-0.00000000e+00, -2.13860523e+00, -4.28704157e-04,
#          9.20792125e+01, -2.19792858e+01, -1.00980344e-02],
#        [ 2.13860523e+00, -0.00000000e+00, -2.13860523e+00,
#         -2.19792858e+01,  9.20792125e+01, -2.19792858e+01],
#        [ 4.28704157e-04,  2.13860523e+00, -0.00000000e+00,
#         -1.00980344e-02, -2.19792858e+01,  9.20792125e+01]])

# %%
K_m_n(xx, X, X_prime, vv, ll)
# Out:
# array([[ 3.31669407e+00,  5.25902008e-01,  1.79929467e-04],
#        [ 2.29480241e+00,  1.24206723e+00,  1.45058425e-03],
#        [ 8.14407112e+00, -5.16536438e+00, -3.97631650e-03],
#        [ 1.12696761e+01, -9.14960826e+00, -2.84950279e-02]])

# %%
kk.compute_K(X, X)
# Out:
# array([[3.74994980e+00, 1.74190505e-01, 1.74590879e-05],
#        [1.74190505e-01, 3.74994980e+00, 1.74190505e-01],
#        [1.74590879e-05, 1.74190505e-01, 3.74994980e+00]])

# %%
kk.compute_Kd(X, X)
# Out:
# array([[-0.00000000e+00,  2.13860523e+00,  4.28704157e-04],
#        [-2.13860523e+00, -0.00000000e+00,  2.13860523e+00],
#        [-4.28704157e-04, -2.13860523e+00, -0.00000000e+00]])

# %%
kk.compute_Kdd(X, X)
# Out:
# array([[ 9.20792125e+01, -2.19792858e+01, -1.00980344e-02],
#        [-2.19792858e+01,  9.20792125e+01, -2.19792858e+01],
#        [-1.00980344e-02, -2.19792858e+01,  9.20792125e+01]])

# %%
kk.compute_Kj(xx,xx)
# Out:
# array([[ 3.7499498 ,  3.31669407, -0.        ,  8.14407112],
#        [ 3.31669407,  3.7499498 , -8.14407112, -0.        ],
#        [-0.        , -8.14407112, 92.0792125 , 61.4431193 ],
#        [ 8.14407112, -0.        , 61.4431193 , 92.0792125 ]])

# %%
xx = np.array([0.1, 0.2])[:,None]

# %%
kk.compute_Kmn(xx, X, X_prime)
# Out:
# array([[ 3.31669407e+00,  2.29480241e+00],
#        [ 5.25902008e-01,  1.24206723e+00],
#        [ 1.79929467e-04,  1.45058425e-03],
#        [ 8.14407112e+00,  1.12696761e+01],
#        [-5.16536438e+00, -9.14960826e+00],
#        [-3.97631650e-03, -2.84950279e-02]])

# %%
c = K_m_n(xx, X, X_prime, vv, ll)

# %%
c
# Out:
# array([[ 3.31669407e+00,  5.25902008e-01,  1.79929467e-04],
#        [ 2.29480241e+00,  1.24206723e+00,  1.45058425e-03],
#        [ 8.14407112e+00, -5.16536438e+00, -3.97631650e-03],
#        [ 1.12696761e+01, -9.14960826e+00, -2.84950279e-02]])

# %%
b
# Out:
# array([[-8.14407112e+00,  5.16536438e+00,  3.97631650e-03],
#        [-1.12696761e+01,  9.14960826e+00,  2.84950279e-02],
#        [-9.14960826e+00,  1.12696761e+01,  1.57245319e-01]])

# %%
np.vstack([a.T,b.T])
# Out:
# array([[ 3.31669407e+00,  2.29480241e+00,  1.24206723e+00],
#        [ 5.25902008e-01,  1.24206723e+00,  2.29480241e+00],
#        [ 1.79929467e-04,  1.45058425e-03,  9.14836623e-03],
#        [-8.14407112e+00, -1.12696761e+01, -9.14960826e+00],
#        [ 5.16536438e+00,  9.14960826e+00,  1.12696761e+01],
#        [ 3.97631650e-03,  2.84950279e-02,  1.57245319e-01]])

# %%
kk.compute_Kmn(xx, X, X_prime)
# Out:
# array([[ 3.31669407e+00,  2.29480241e+00],
#        [ 5.25902008e-01,  1.24206723e+00],
#        [ 1.79929467e-04,  1.45058425e-03],
#        [ 8.14407112e+00,  1.12696761e+01],
#        [-5.16536438e+00, -9.14960826e+00],
#        [-3.97631650e-03, -2.84950279e-02]])

# %%
c.shape
# Out:
# (4, 3)

# %%
rbf_n_d(xx,xx, vv, ll)
# Out:
# array([[ -0.        ,   8.14407112,  11.26967615],
#        [ -8.14407112,  -0.        ,   8.14407112],
#        [-11.26967615,  -8.14407112,  -0.        ]])

# %%
kk.compute_Kd(xx, xx)
# Out:
# array([[ -0.        ,   8.14407112,  11.26967615],
#        [ -8.14407112,  -0.        ,   8.14407112],
#        [-11.26967615,  -8.14407112,  -0.        ]])

# %%
rbf(xx, xx, vv, ll)
# Out:
# array([[3.7499498 , 3.31669407, 2.29480241],
#        [3.31669407, 3.7499498 , 3.31669407],
#        [2.29480241, 3.31669407, 3.7499498 ]])

# %%
kk.compute_Kmn(xx, X, X_prime)
# Out:
# array([[ 3.31669407e+00,  2.29480241e+00],
#        [ 5.25902008e-01,  1.24206723e+00],
#        [ 1.79929467e-04,  1.45058425e-03],
#        [ 8.14407112e+00,  1.12696761e+01],
#        [-5.16536438e+00, -9.14960826e+00],
#        [-3.97631650e-03, -2.84950279e-02]])

# %%
m.V.value
# Out:
# array([[-0.01137682],
#        [ 1.35018367],
#        [ 2.45534045],
#        [ 0.52632613],
#        [ 1.53772615],
#        [ 1.07573475]])

# %%
kmn = K_m_n(xx, X, X_prime, vv, ll)
kmm = K_m_m(X, X_prime, vv, ll)
L = np.linalg.cholesky(kmm)
import scipy
A = scipy.linalg.solve(L, kmn, lower = True)
# construct the conditional mean
fmean = np.matmul(A.T, m.V.value)

fvar = rbf(xx, xx, ll, vv) - np.matmul(A.T, A)

# %%
fmean
# Out:
# array([[-0.35260283],
#        [-0.22090287]])

# %%
rbf(xx, xx, ll, vv)
# Out:
# array([[0.201805  , 0.20173326],
#        [0.20173326, 0.201805  ]])

# %%
def is_pos_def(x):
    return np.all(np.linalg.eigvals(x) > 0)

# %%
is_pos_def(fvar)
# Out:
# False

# %%
 # compute kernel stuff
    num_data = tf.shape(X)[0]  # M
    num_func = tf.shape(f)[1]  # K
    Kmn = kern.K(X, Xnew)
    Kmm = kern.K(X) + tf.eye(num_data, dtype=float_type) * settings.numerics.jitter_level
    Lm = tf.cholesky(Kmm)

    # Compute the projection matrix A
    A = tf.matrix_triangular_solve(Lm, Kmn, lower=True)

    # compute the covariance due to the conditioning
    if full_cov:
        fvar = kern.K(Xnew) - tf.matmul(A, A, transpose_a=True)
        shape = tf.stack([num_func, 1, 1])
    else:
        fvar = kern.Kdiag(Xnew) - tf.reduce_sum(tf.square(A), 0)
        shape = tf.stack([num_func, 1])
    fvar = tf.tile(tf.expand_dims(fvar, 0), shape)  # K x N x N or K x N

    # another backsubstitution in the unwhitened case
    if not whiten:
        A = tf.matrix_triangular_solve(tf.transpose(Lm), A, lower=False)

    # construct the conditional mean
    fmean = tf.matmul(A, f, transpose_a=True)

    if q_sqrt is not None:
        if q_sqrt.get_shape().ndims == 2:
            LTA = A * tf.expand_dims(tf.transpose(q_sqrt), 2)  # K x M x N
        elif q_sqrt.get_shape().ndims == 3:
            L = tf.matrix_band_part(tf.transpose(q_sqrt, (2, 0, 1)), -1, 0)  # K x M x M
            A_tiled = tf.tile(tf.expand_dims(A, 0), tf.stack([num_func, 1, 1]))
            LTA = tf.matmul(L, A_tiled, transpose_a=True)  # K x M x N
        else:  # pragma: no cover
            raise ValueError("Bad dimension for q_sqrt: %s" %
                             str(q_sqrt.get_shape().ndims))
        if full_cov:
            fvar = fvar + tf.matmul(LTA, LTA, transpose_a=True)  # K x N x N
        else:
            fvar = fvar + tf.reduce_sum(tf.square(LTA), 1)  # K x N
    fvar = tf.transpose(fvar)  # N x K or N x N x K

    return fmean, fvar
