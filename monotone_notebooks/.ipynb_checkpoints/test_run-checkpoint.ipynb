# %%
import numpy as np
import gpflow
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_context("talk", font_scale = 1.4)
X = np.linspace(0.,1, 2)[:,None]
X_prime = np.linspace(0, 1, 20)[:,None]
values = np.ones(X_prime.shape[0])
Y = 5*X

plt.plot(X, Y)

# %%
import sys
sys.path.append('../')
from GPMonotone.ker_w_der import ExtendRBF1D
from GPMonotone.monotone_gpmc import MonotoneGPMC

# %%
K = ExtendRBF1D()

# %%
m = MonotoneGPMC(X, Y, X_prime, values)
m.likelihood.noise_variance = 0.01
m.likelihood.noise_variance.fixed = True

# %%
m.kern.lengthscale.prior = gpflow.priors.Gamma(1., 1.)
m.kern.signal_variance.prior = gpflow.priors.Gamma(1.,1.)
m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>monotonic_model.V</td><td>[[0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]</br> [0.]]</td><td>N([0.],[1.])</td><td>(none)</td></tr><tr><td>monotonic_model.kern.lengthscale</td><td>[1.]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>monotonic_model.kern.signal_variance</td><td>[1.]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>monotonic_model.likelihood.noise_variance</td><td>[0.01]</td><td>None</td><td>[FIXED]</td></tr></table>

# %%
m.optimize(maxiter=150) # start near MAP
# Out:
#       fun: array([26.04798482])
#  hess_inv: <24x24 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 4.92099363e-06,  3.51422776e-05, -5.16833325e-07,  1.59440729e-06,
#         5.96065640e-07,  3.79499922e-07,  2.01730625e-07,  1.43353932e-07,
#         1.22790053e-07,  1.02979745e-07,  7.58706146e-08,  4.70081862e-08,
#         1.94801877e-08, -9.55872547e-09, -4.58718476e-08, -9.40544828e-08,
#        -1.47566009e-07, -1.76445968e-07, -1.53958888e-07, -1.00968537e-07,
#        -5.26192116e-08, -2.11884868e-08, -9.39697160e-06,  1.42167822e-05])
#   message: 'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 66
#       nit: 40
#    status: 0
#   success: True
#         x: array([ 7.31350140e-04,  2.64295116e+00, -5.16833325e-07,  1.59440729e-06,
#         5.96065640e-07,  3.79499922e-07,  2.01730625e-07,  1.43353932e-07,
#         1.22790053e-07,  1.02979745e-07,  7.58706146e-08,  4.70081862e-08,
#         1.94801877e-08, -9.55872547e-09, -4.58718476e-08, -9.40544828e-08,
#        -1.47566009e-07, -1.76445968e-07, -1.53958888e-07, -1.00968537e-07,
#        -5.26192116e-08, -2.11884868e-08, -5.23632085e-01,  3.56630338e+00])

# %%
m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>monotonic_model.V</td><td>[[ 7.31350140e-04]</br> [ 2.64295116e+00]</br> [-5.16833325e-07]</br> [ 1.59440729e-06]</br> [ 5.96065640e-07]</br> [ 3.79499922e-07]</br> [ 2.01730625e-07]</br> [ 1.43353932e-07]</br> [ 1.22790053e-07]</br> [ 1.02979745e-07]</br> [ 7.58706146e-08]</br> [ 4.70081862e-08]</br> [ 1.94801877e-08]</br> [-9.55872547e-09]</br> [-4.58718476e-08]</br> [-9.40544828e-08]</br> [-1.47566009e-07]</br> [-1.76445968e-07]</br> [-1.53958888e-07]</br> [-1.00968537e-07]</br> [-5.26192116e-08]</br> [-2.11884868e-08]]</td><td>N([0.],[1.])</td><td>(none)</td></tr><tr><td>monotonic_model.kern.lengthscale</td><td>[0.46522141]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>monotonic_model.kern.signal_variance</td><td>[3.59417256]</td><td>Ga([1.],[1.])</td><td>+ve</td></tr><tr><td>monotonic_model.likelihood.noise_variance</td><td>[0.01]</td><td>None</td><td>[FIXED]</td></tr></table>

# %%
samples = m.sample(200, Lmax = 20, epsilon = 0.01, thin = 5, burn = 1000, verbose= True)
# Out:
# burn-in sampling started
# Iteration:  100 	 Acc Rate:  91.0 %
# Iteration:  200 	 Acc Rate:  96.0 %
# Iteration:  300 	 Acc Rate:  87.0 %
# Iteration:  400 	 Acc Rate:  76.0 %
# Iteration:  500 	 Acc Rate:  73.0 %
# Iteration:  600 	 Acc Rate:  90.0 %
# Iteration:  700 	 Acc Rate:  86.0 %
# Iteration:  800 	 Acc Rate:  92.0 %
# Iteration:  900 	 Acc Rate:  82.0 %
# Iteration:  1000 	 Acc Rate:  83.0 %
# burn-in sampling ended
# Iteration:  100 	 Acc Rate:  89.0 %
# Iteration:  200 	 Acc Rate:  92.0 %
# Iteration:  300 	 Acc Rate:  96.0 %
# Iteration:  400 	 Acc Rate:  98.0 %
# Iteration:  500 	 Acc Rate:  98.0 %
# Iteration:  600 	 Acc Rate:  78.0 %
# Iteration:  700 	 Acc Rate:  78.0 %
# Iteration:  800 	 Acc Rate:  84.0 %
# Iteration:  900 	 Acc Rate:  88.0 %
# Iteration:  1000 	 Acc Rate:  90.0 %

# %%
plt.figure(figsize=(16, 4))
plt.plot(samples)
# Out:
# [<matplotlib.lines.Line2D at 0x107575c10>,
#  <matplotlib.lines.Line2D at 0x1a21acea50>,
#  <matplotlib.lines.Line2D at 0x1a21ace890>,
#  <matplotlib.lines.Line2D at 0x1a2205aa10>,
#  <matplotlib.lines.Line2D at 0x1a2205aa50>,
#  <matplotlib.lines.Line2D at 0x1a224b7690>,
#  <matplotlib.lines.Line2D at 0x1a224b73d0>,
#  <matplotlib.lines.Line2D at 0x1a224b7490>,
#  <matplotlib.lines.Line2D at 0x1a222db790>,
#  <matplotlib.lines.Line2D at 0x1a222dbbd0>,
#  <matplotlib.lines.Line2D at 0x1a220b1cd0>,
#  <matplotlib.lines.Line2D at 0x1a220b1d90>,
#  <matplotlib.lines.Line2D at 0x1a220b1e50>,
#  <matplotlib.lines.Line2D at 0x1a220b1f10>,
#  <matplotlib.lines.Line2D at 0x1a220b1fd0>,
#  <matplotlib.lines.Line2D at 0x1a220910d0>,
#  <matplotlib.lines.Line2D at 0x1a22091190>,
#  <matplotlib.lines.Line2D at 0x1a22091250>,
#  <matplotlib.lines.Line2D at 0x1a22091310>,
#  <matplotlib.lines.Line2D at 0x1a220913d0>,
#  <matplotlib.lines.Line2D at 0x1a2205abd0>,
#  <matplotlib.lines.Line2D at 0x1a22091550>,
#  <matplotlib.lines.Line2D at 0x1a22091610>,
#  <matplotlib.lines.Line2D at 0x1a220916d0>]

# %%
sample_df = m.get_samples_df(samples)
sample_df.head()
# Out:
#                                    monotonic_model.V  \
# 0  [[-0.0052461795573557485], [2.604460663014037]...
# 1  [[0.025978577555463626], [2.60353856930793], [...
# 2  [[0.0008666300099246464], [2.551355478576617],...
# 3  [[0.06427736117347335], [2.50353259393343], [-...
# 4  [[-0.039069534255097696], [2.416829515373308],...
#
#   monotonic_model.kern.lengthscale monotonic_model.kern.signal_variance  \
# 0             [0.5163593521470299]                 [3.8152509620676214]
# 1            [0.49049115624267897]                 [3.8728030451925517]
# 2             [0.5276467038827062]                  [4.234428215688206]
# 3            [0.46758785173284884]                 [3.9629232765081235]
# 4             [0.5706230154354454]                  [4.472214974788245]
#
#   monotonic_model.likelihood.noise_variance
# 0                                    [0.01]
# 1                                    [0.01]
# 2                                    [0.01]
# 3                                    [0.01]
# 4                                    [0.01]

# %%
plt.plot(sample_df['monotonic_model.kern.signal_variance'])

# %%
plt.plot(sample_df['monotonic_model.kern.lengthscale'])

# %%
plt.scatter(sample_df['monotonic_model.kern.signal_variance'], sample_df['monotonic_model.kern.lengthscale'])

# %%
sample_df = m.get_samples_df(samples)
#plot the function posterior
xx = np.linspace(-0.1, 1.1, 100)[:,None]
plt.figure(figsize=(12, 6))
for i, s in sample_df.iterrows():
    m.set_parameter_dict(s)
    f = m.predict_f_samples(xx, 1)
    plt.plot(xx, f[0,:,:], 'b', lw=2, alpha = 0.05)
    
plt.plot(X, Y, 'kx', mew=2)
_ = plt.xlim(xx.min(), xx.max())
_ = plt.ylim(0, 6)

# %%
ll = kk.lengthscale.value
vv = kk.signal_variance.value

# %%
def rbf(x1, x2, var, l):
    diff = x1 - x2.T
    sqr = diff**2
    val = var*np.exp(-1./(2*l**2)*sqr)
    return val

def rbf_d(x1, x2, var, l):
    diff = x1 - x2.T
    sqr = diff**2
    val = var/l**2*np.exp(-1./(2*l**2)*sqr)*(1 - 1./l**2*sqr)
    return val

def rbf_n_d(x1, x2, var, l):
    """
    cov between GP at x1 points and derivative of GP at x2 points
    """
    diff = x1 - x2.T
    sqr = diff**2
    val = -var/l**2*np.exp(-1./(2*l**2)*sqr)*diff
    return val

def K_m_m(X, X_prime, var, l):
    k1 = rbf(X, X, var, l)
    k2 = rbf_n_d(X, X_prime, var, l)
    k3 = k2.T
    k4 = rbf_d(X_prime, X_prime, var, l)
    K11 = np.hstack([k1,k2])
    K22 = np.hstack([k3, k4])
    KK = np.vstack([K11, K22])
    return KK

def K_m_n(Xnew, X, X_prime, var, l):
    k1 = rbf(X, Xnew, var, l)
    k2 = rbf_n_d(Xnew, X_prime, var, l)
    kk = np.vstack([k1, k2.T])
    return kk

# %%
rbf(X, X, vv, ll)

# %%
rbf_d(X, X, vv, ll)

# %%
rbf_n_d(X, X, vv, ll)

# %%
K_m_m(X, X_prime, vv, ll)

# %%
K_m_n(xx, X, X_prime, vv, ll)

# %%
b

# %%
kk.compute_K(X, X)

# %%
kk.compute_Kd(X, X)

# %%
kk.compute_Kdd(X, X)

# %%
kk.compute_Kj(xx,xx)

# %%
xx = np.array([0.1, 0.2])[:,None]

# %%
kk.compute_Kmn(xx, X, X_prime)

# %%
c = K_m_n(xx, X, X_prime, vv, ll)

# %%
c

# %%
b

# %%
kk.compute_Kmn(xx, X, X_prime)

# %%
c.shape

# %%
rbf_n_d(xx,xx, vv, ll)

# %%
kk.compute_Kd(xx, xx)

# %%
rbf(xx, xx, vv, ll)

# %%
kk.compute_Kmn(xx, X, X_prime)

# %%
m.V.value

# %%
kmn = K_m_n(xx, X, X_prime, vv, ll)
kmm = K_m_m(X, X_prime, vv, ll)
L = np.linalg.cholesky(kmm)
import scipy
A = scipy.linalg.solve(L, kmn, lower = True)
# construct the conditional mean
fmean = np.matmul(A.T, m.V.value)

fvar = rbf(xx, xx, ll, vv) - np.matmul(A.T, A)

# %%
rbf(xx, xx, ll, vv)

# %%
rbf(xx, xx, ll, vv)

# %%
def is_pos_def(x):
    return np.all(np.linalg.eigvals(x) > 0)

# %%
is_pos_def(fvar)

# %%
 # compute kernel stuff
    num_data = tf.shape(X)[0]  # M
    num_func = tf.shape(f)[1]  # K
    Kmn = kern.K(X, Xnew)
    Kmm = kern.K(X) + tf.eye(num_data, dtype=float_type) * settings.numerics.jitter_level
    Lm = tf.cholesky(Kmm)

    # Compute the projection matrix A
    A = tf.matrix_triangular_solve(Lm, Kmn, lower=True)

    # compute the covariance due to the conditioning
    if full_cov:
        fvar = kern.K(Xnew) - tf.matmul(A, A, transpose_a=True)
        shape = tf.stack([num_func, 1, 1])
    else:
        fvar = kern.Kdiag(Xnew) - tf.reduce_sum(tf.square(A), 0)
        shape = tf.stack([num_func, 1])
    fvar = tf.tile(tf.expand_dims(fvar, 0), shape)  # K x N x N or K x N

    # another backsubstitution in the unwhitened case
    if not whiten:
        A = tf.matrix_triangular_solve(tf.transpose(Lm), A, lower=False)

    # construct the conditional mean
    fmean = tf.matmul(A, f, transpose_a=True)

    if q_sqrt is not None:
        if q_sqrt.get_shape().ndims == 2:
            LTA = A * tf.expand_dims(tf.transpose(q_sqrt), 2)  # K x M x N
        elif q_sqrt.get_shape().ndims == 3:
            L = tf.matrix_band_part(tf.transpose(q_sqrt, (2, 0, 1)), -1, 0)  # K x M x M
            A_tiled = tf.tile(tf.expand_dims(A, 0), tf.stack([num_func, 1, 1]))
            LTA = tf.matmul(L, A_tiled, transpose_a=True)  # K x M x N
        else:  # pragma: no cover
            raise ValueError("Bad dimension for q_sqrt: %s" %
                             str(q_sqrt.get_shape().ndims))
        if full_cov:
            fvar = fvar + tf.matmul(LTA, LTA, transpose_a=True)  # K x N x N
        else:
            fvar = fvar + tf.reduce_sum(tf.square(LTA), 1)  # K x N
    fvar = tf.transpose(fvar)  # N x K or N x N x K

    return fmean, fvar
